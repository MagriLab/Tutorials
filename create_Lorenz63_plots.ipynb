# %% [markdown]
# # LSTMs for Chaotic Dynamics
#
# ### Authors: Elise Özalp (elise.ozalp@imperial.ac.uk), Luca Magri (luca.magri@imperial.ac.uk)
#
#
# This notebook explores the application of Long short-term memory (LSTM) networks in learning chaotic dynamics and their stability properties, focusing on the Lorenz-63 system. Chaotic systems like Lorenz-63 exhibit complex behavior, making them challenging for modeling. We discuss the training process, model evaluation, and the interpretability of LSTM predictions in the context of chaotic systems. The results obtained provide valuable insights into the potential of deep learning models for understanding and predicting chaotic behavior.
#
#
# #### Lorenz-63 System
#
# The Lorenz-63 system is a set of ordinary differential equations that describe a simplified atmospheric convection model. It is a classic example of a chaotic system, characterized by sensitive dependence on initial conditions. In this notebook, we delve into the dynamics of the Lorenz-63 system and discuss the challenges of capturing its chaotic nature.
#
# #### LSTMs and Chaotic Dynamics
#
# LSTM are a type of recurrent neural network (RNN), that have shown promise in capturing intricate temporal dependencies in sequential data. We explore how LSTMs can be applied to learn and predict the chaotic behavior inherent in systems like Lorenz-63. Through this analysis, we aim to gain insights into the capabilities and limitations of LSTMs in handling chaotic dynamics.
#
# Feel free to adapt and expand upon this structure to suit the specific details and findings of your analysis.
#
#
# This work is based on
#
# - Elise Özalp, Georgios Margazoglou, Luca Magri; Reconstruction, forecasting, and stability of chaotic dynamics from partial data. Chaos, September 2023; 33 (9): 093107. [https://doi.org/10.1063/5.0159479]( https://doi.org/10.1063/5.0159479)

# %%
import os 
os.environ["KMP_AFFINITY"] = "noverbose"
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import logging
logging.getLogger('tensorflow').setLevel(logging.ERROR)
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats 
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
tf.config.set_visible_devices([], 'GPU')
tf.autograph.set_verbosity(3)


from dynamicalsystems.tools import solve_ode_LEs
from lstm.lstm import TensorFlowLSTM
from lstm.lyapunov_tools import compute_lyapunov_exp_lstm

#Latex
mpl.rc('text', usetex = True)
mpl.rc('font', family = 'serif')
# Out:
# 2024-01-23 14:36:46.116954: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-23 14:36:46.190318: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-23 14:36:47.240075: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# #
#
# ## Lorenz-63 System
#
# The Lorenz-63 system is a set of ordinary differential equations that describe a simplified atmospheric convection model. It is a classic example of a chaotic system, characterized by sensitive dependence on initial conditions. In this notebook, we delve into the dynamics of the Lorenz-63 system and discuss the challenges of capturing its chaotic nature.
#
# The system is given by
#
# \begin{align*}
# \frac{dx}{dt} &= \sigma \cdot (y - x) \\
# \frac{dy}{dt} &= x \cdot (\rho - z) - y \\
# \frac{dz}{dt} &= x \cdot y - \beta \cdot z
# \end{align*}
#
#
# where  x, y, z are the state variables and $\beta$, $\rho $, and  $\sigma $ are system parameters. For $\beta = \frac{8}{3}, \rho =28, \sigma = 10$, the system exhibits chaotic behaviour. We select the initial condition $\begin{bmatrix} x(0); y(0); z(0) \end{bmatrix} = \begin{bmatrix} 0; 1; 1 \end{bmatrix}$. For this system, the largest Lyapunov exponent is given by $\lambda\approx 0.9$.
#
# ### Generating the data:
# We solve the system using RK45, remove an initial transient and then normalize the input between $\begin{bmatrix}-1, 1\end{bmatrix}$ (for better training).

# %%
def lorenz63(u, params):
    beta, rho, sigma = params
    x, y, z = u
    return np.array([sigma*(y-x), x*(rho-z)-y, x*y-beta*z])

def l63jac(u, params):
    beta, rho, sigma = params # Unpack the constants vector
    x, y, z          = u  # Unpack the state vector

    #Jacobian
    J = np.array([[-sigma, sigma,     0],
                  [ rho-z,    -1,    -x],
                  [     y,     x, -beta]])
    return J

# %%
dim = 3
params = [2.667, 28, 10]  # beta, rho, sigma
u0 = np.array([0.0, 1.0, 1.0])  # initial condition

dt = 0.01  # time step
t_lyap = 0.9**(-1)  # Lyapunov time

N_lyap = int(t_lyap/dt)
N_trans = 00  # initial transient to discard
N_total = 100*N_lyap + N_trans
time_array, U_rk4, LEs, ILEs = solve_ode_LEs(N_total, N_trans, dt, u0, lorenz63, l63jac, params,  dim=3)
time_array = time_array[N_trans:]
U_rk4 = U_rk4[N_trans:].astype(np.float32)
# U_rk4 = U_rk4/np.max(U_rk4, axis=0)  # remove the initial transient
time_array_lyap = np.arange(0, len(time_array), step=dt)/0.9
print(f"Shape of solution generated with RK45: {U_rk4.shape}")
# Out:
# Number of timesteps 11100
# Number of timesteps in test 11100
# Lyapunov Exponents: [ 8.43896488e-01  8.04621137e-03 -1.45188440e+01]
# Shape of solution generated with RK45: (11101, 3)

# %%
ax = plt.figure(figsize=(10,5)).add_subplot(projection='3d')

# Make the line multi-coloured by plotting it in segments of length s which
# change in colour across the whole time series.
n = len(U_rk4[:])
s = 5000
cmap = plt.cm.winter  # winter
cmap_2 = plt.cm.autumn  # autumn

for i in range(0, n - s, s):
    ax.plot(U_rk4[i:i+s+1, 0], U_rk4[i:i+s+1, 1], U_rk4[i:i+s+1, 2], color=cmap(i/n), alpha=0.4)
ax.zaxis.labelpad=-2.5
ax.set_zlabel('z', fontsize=12)
ax.set_xlabel('x', fontsize=12)
ax.set_ylabel('y', fontsize=12)
# ax.set_zlabel('z', fontsize=12)

plt.show()

# %%
rho = np.arange(1, 30, step=0.1)
sigma=10
print(rho.shape)
def fixed_point(beta, rho, sign=1):
    x_star = sign * np.sqrt(beta * (rho - 1))
    y_star = x_star
    z_star = rho - 1
    return np.array([x_star, y_star, z_star])
beta = 8/3
u_minus = fixed_point(beta, rho, sign=-1)
u_plus = fixed_point(beta, rho, sign=1)
rho_zero = np.arange(-10, 1, step=0.1)
u_zero = np.zeros((3, rho_zero.shape[0]))

rho_zero_unstable = np.arange(1, 30, step=0.1)
u_zero_unstable  = np.zeros((3, rho_zero_unstable.shape[0]))

fig, axs = plt.subplots(1, 3, figsize=(11.4, 3))
for i in range(3):
    axs[i].plot(rho[rho<sigma*(sigma+beta+3)/(sigma-beta-1)], u_minus[i, rho<sigma*(sigma+beta+3)/(sigma-beta-1)], 'b') 
    axs[i].plot(rho[rho<sigma*(sigma+beta+3)/(sigma-beta-1)], u_plus[i, rho<sigma*(sigma+beta+3)/(sigma-beta-1)], 'b') 
    axs[i].plot(rho_zero, u_zero[i], 'b')
    axs[i].plot(rho_zero_unstable, u_zero_unstable[i], 'r--')
    axs[i].plot(rho[rho>sigma*(sigma+beta+3)/(sigma-beta-1)], u_minus[i, rho>sigma*(sigma+beta+3)/(sigma-beta-1)], 'r--')
    axs[i].plot(rho[rho>sigma*(sigma+beta+3)/(sigma-beta-1)], u_plus[i, rho>sigma*(sigma+beta+3)/(sigma-beta-1)], 'r--')
    axs[i].set_xlabel(r'$\rho$', fontsize=12)
axs[0].set_ylabel(r'$x^*$', fontsize=12, labelpad=1)
axs[1].set_ylabel(r'$y^*$', fontsize=12, labelpad=1)
axs[2].set_ylabel(r'$z^*$', fontsize=12, labelpad=1)
axs[2].plot(rho_zero, u_zero[2], 'b', label="stable")
axs[2].plot(rho_zero_unstable, u_zero_unstable[2], 'r--', label="unstable")

fig.legend(bbox_to_anchor=(1.021,0.6), fontsize=12)
# fig.tight_layout()
# plt.savefig("bifurcation_lorenz63.png", dpi=100, bbox_inches='tight')
# Out:
# (290,)

# %%
N_plot=10000
plt.plot(time_array_lyap[:N_plot], LEs[:N_plot, 0], label=r"$\lambda_1$")
plt.plot(time_array_lyap[:N_plot], LEs[:N_plot, 1], label=r"$\lambda_2$")
plt.plot(time_array_lyap[:N_plot], LEs[:N_plot, 2], label=r"$\lambda_3$")
# plt.title("Covergence of Lyapunov exponents")
# plt.ylabel(r"$\lambda_i$")
plt.xlabel(r"$t_p$")
plt.legend()
# plt.savefig("Convergence_LEs.png", dpi=100)

# %%
plt.plot(ILEs[:,:])
print(np.mean(ILEs, axis=0))
# plt.yscale('symlog')
# Out:
# [ 8.44079835e-01  7.78377747e-03 -1.45188636e+01]

# %% [markdown]
# #
#
# ## Preparing the data for training
#
#
# #### 1. Splitting Data
# - Divide the dataset into three sets: training, testing, and validation data.
#
# #### 2. Time Window for LSTM
# - The LSTM takes data of the following input shape (batch size, window size, dimension of observations). The window size refers to the number of consecutive time steps.

# %%
def split_data(U, train_size, valid_size, test_size):
    return U[:train_size], U[train_size: train_size + valid_size],  U[train_size + valid_size : train_size + valid_size+test_size]

def create_windows(series, window_size, batch_size, shuffle_buffer):
    n = series.shape[1]
    m = series.shape[0]
    dataset = tf.data.Dataset.from_tensor_slices(series)
    dataset = dataset.window(size=window_size + 1, shift=1, drop_remainder=True)
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))
    dataset = dataset.shuffle(shuffle_buffer).map(
        lambda window: (window[:-1], window[1:])
    )
    dataset = dataset.padded_batch(batch_size, padded_shapes=([None, n], [None, n]))
    return  dataset

# %%
# set sizes
train_size = 20000
valid_size = 5000
test_size = 25000

U_train, U_valid, U_test = split_data(U_rk4, train_size, valid_size, test_size)
time_train, time_valid, time_test = split_data(time_array_lyap, train_size, valid_size, test_size)

fig, axs = plt.subplots(3, sharex=True, sharey=True)
axs[0].plot(time_train, U_train[:, 0], time_valid, U_valid[:, 0], time_test, U_test[:, 0])
axs[1].plot(time_train, U_train[:, 1], time_valid, U_valid[:, 1], time_test, U_test[:, 1])
axs[0].set_ylabel('x')
axs[1].set_ylabel('y')
axs[2].plot(time_train, U_train[:, 2], label='Training Data')
axs[2].plot(time_valid, U_valid[:, 2], label='Validation Data')
axs[2].plot(time_test, U_test[:, 2], label='Test Data')
axs[2].set_ylabel('z')
axs[2].set_xlabel('Lyapunov Time')
# ax3.set_xlim(0,1)
axs[2].legend(loc='center left', bbox_to_anchor=(1, 1.5))
plt.show()

# %%
batch_size = 128  # Choose your desired batch size
window_size = 10  # Choose your desired window size
train_dataset = create_windows(U_train, window_size=10, batch_size=128, shuffle_buffer=1)

valid_dataset = create_windows(U_valid, window_size=10, batch_size=128, shuffle_buffer=1)

for input, label in train_dataset.take(1):
    print(f"LSTM takes inputs: (batch size, window size, dimension of observations)")
    print(f"Input shape {input.shape} \nLabel shape {label.shape}")
# Out:
# LSTM takes inputs: (batch size, window size, dimension of observations)
# Input shape (128, 10, 3)
# Label shape (128, 10, 3)

# %% [markdown]
# # LSTMs
#
# - LSTMs feature three key gates—input, forget, and output gates—that control the flow of information within the cell.
# - Information of previous cells is kept in both the hidden and cell states.
#   - The hidden state encapsulates long-term information, while the cell state retains short-term information.
#
# <p align="center">
#   <img src="Images/lstm_cell.png" alt="LSTM cell" width="30%"/>
# </p>

# %% [markdown]
# ## Open-Loop Mode
#
# The network works in an open-loop configuration during training and validation with the output at each time step depending on current and previous inputs within the time window, and the LSTM’s states are reset to zero at the start of each input sequence.
#
# <p align="center">
#   <img src="Images/lstm_open_loop.png" alt="LSTM Open Loop" width="30%"/>
# </p>
#
#
# ## Closed-Loop Mode
#
# After training, the network is evaluated on test data with fixed weights and biases, operating in a closed-loop configuration. After a warm-up of one
# time window, the network can make long-term predictions in closed loop mode, even if no data is available, and the states of the LSTM are retained across time steps. The network predicts the next time step, and the prediction is used as an input for the next time step, which allows the autonomous evolution of the LSTM.
#
# <p align="center">
#   <img src="Images/lstm_closed_loop.png" alt="LSTM Closed Loop" width="30%"/>
# </p>

# %%
tf_lstm = TensorFlowLSTM(hidden_size=30, window_size=window_size, observation_dimension=3)
tf_lstm(input)
tf_lstm.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  LSTM_1 (LSTM)               (128, 10, 30)             4080
#
#  DenseLayer (Dense)          (128, 10, 3)              93
#
# =================================================================
# Total params: 4,173
# Trainable params: 4,173
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = tf_lstm.model.fit(train_dataset, validation_data = valid_dataset, epochs = 100)
# Out:
# Epoch 1/100
# 157/157 [==============================] - 7s 27ms/step - loss: 0.0625 - mse: 0.0625 - val_loss: 0.0209 - val_mse: 0.0209
# Epoch 2/100
# 157/157 [==============================] - 3s 20ms/step - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 3/100
# 157/157 [==============================] - 3s 20ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 4/100
# 157/157 [==============================] - 3s 21ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 5/100
# 157/157 [==============================] - 3s 20ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 6/100
# 157/157 [==============================] - 3s 20ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 9.9170e-04 - val_mse: 9.9170e-04
# Epoch 7/100
# 157/157 [==============================] - 3s 21ms/step - loss: 8.6498e-04 - mse: 8.6498e-04 - val_loss: 7.1930e-04 - val_mse: 7.1930e-04
# Epoch 8/100
# 157/157 [==============================] - 3s 21ms/step - loss: 6.5392e-04 - mse: 6.5392e-04 - val_loss: 5.5913e-04 - val_mse: 5.5913e-04
# Epoch 9/100
# 157/157 [==============================] - 3s 20ms/step - loss: 5.1942e-04 - mse: 5.1942e-04 - val_loss: 4.4699e-04 - val_mse: 4.4699e-04
# Epoch 10/100
# 157/157 [==============================] - 3s 21ms/step - loss: 4.1970e-04 - mse: 4.1970e-04 - val_loss: 3.6252e-04 - val_mse: 3.6252e-04
# Epoch 11/100
# 157/157 [==============================] - 3s 20ms/step - loss: 3.4043e-04 - mse: 3.4043e-04 - val_loss: 2.9452e-04 - val_mse: 2.9452e-04
# Epoch 12/100
# 157/157 [==============================] - 3s 20ms/step - loss: 2.7525e-04 - mse: 2.7525e-04 - val_loss: 2.3735e-04 - val_mse: 2.3735e-04
# Epoch 13/100
# 157/157 [==============================] - 3s 20ms/step - loss: 2.2148e-04 - mse: 2.2148e-04 - val_loss: 1.9194e-04 - val_mse: 1.9194e-04
# Epoch 14/100
# 157/157 [==============================] - 3s 21ms/step - loss: 1.7720e-04 - mse: 1.7720e-04 - val_loss: 1.5371e-04 - val_mse: 1.5371e-04
# Epoch 15/100
# 157/157 [==============================] - 3s 20ms/step - loss: 1.4127e-04 - mse: 1.4127e-04 - val_loss: 1.2237e-04 - val_mse: 1.2237e-04
# Epoch 16/100
# 157/157 [==============================] - 3s 20ms/step - loss: 1.1233e-04 - mse: 1.1233e-04 - val_loss: 9.7272e-05 - val_mse: 9.7272e-05
# Epoch 17/100
# 157/157 [==============================] - 3s 20ms/step - loss: 8.9278e-05 - mse: 8.9278e-05 - val_loss: 7.8045e-05 - val_mse: 7.8045e-05
# Epoch 18/100
# 157/157 [==============================] - 4s 22ms/step - loss: 7.1259e-05 - mse: 7.1259e-05 - val_loss: 6.3512e-05 - val_mse: 6.3512e-05
# Epoch 19/100
# 157/157 [==============================] - 3s 20ms/step - loss: 5.7256e-05 - mse: 5.7256e-05 - val_loss: 5.1539e-05 - val_mse: 5.1539e-05
# Epoch 20/100
# 157/157 [==============================] - 3s 20ms/step - loss: 4.6510e-05 - mse: 4.6510e-05 - val_loss: 4.1847e-05 - val_mse: 4.1847e-05
# Epoch 21/100
# 157/157 [==============================] - 3s 20ms/step - loss: 3.8474e-05 - mse: 3.8474e-05 - val_loss: 3.5457e-05 - val_mse: 3.5457e-05
# Epoch 22/100
# 157/157 [==============================] - 4s 21ms/step - loss: 3.2359e-05 - mse: 3.2359e-05 - val_loss: 3.0311e-05 - val_mse: 3.0311e-05
# Epoch 23/100
# 157/157 [==============================] - 3s 20ms/step - loss: 2.7803e-05 - mse: 2.7803e-05 - val_loss: 2.6180e-05 - val_mse: 2.6180e-05
# Epoch 24/100
# 157/157 [==============================] - 3s 20ms/step - loss: 2.4373e-05 - mse: 2.4373e-05 - val_loss: 2.3263e-05 - val_mse: 2.3263e-05
# Epoch 25/100
# 157/157 [==============================] - 3s 20ms/step - loss: 2.1725e-05 - mse: 2.1725e-05 - val_loss: 2.0947e-05 - val_mse: 2.0947e-05
# Epoch 26/100
# 157/157 [==============================] - 3s 20ms/step - loss: 1.9613e-05 - mse: 1.9613e-05 - val_loss: 1.9292e-05 - val_mse: 1.9292e-05
# Epoch 27/100
# 157/157 [==============================] - 3s 20ms/step - loss: 1.7842e-05 - mse: 1.7842e-05 - val_loss: 1.7674e-05 - val_mse: 1.7674e-05
# Epoch 28/100
# 157/157 [==============================] - 3s 21ms/step - loss: 1.6335e-05 - mse: 1.6335e-05 - val_loss: 1.6115e-05 - val_mse: 1.6115e-05
# Epoch 29/100
# 157/157 [==============================] - 3s 20ms/step - loss: 1.4933e-05 - mse: 1.4933e-05 - val_loss: 1.4941e-05 - val_mse: 1.4941e-05
# Epoch 30/100
# 157/157 [==============================] - 3s 20ms/step - loss: 1.3651e-05 - mse: 1.3651e-05 - val_loss: 1.3521e-05 - val_mse: 1.3521e-05
# Epoch 31/100
# 157/157 [==============================] - 4s 21ms/step - loss: 1.2443e-05 - mse: 1.2443e-05 - val_loss: 1.2363e-05 - val_mse: 1.2363e-05
# Epoch 32/100
# 157/157 [==============================] - 4s 21ms/step - loss: 1.1262e-05 - mse: 1.1262e-05 - val_loss: 1.1216e-05 - val_mse: 1.1216e-05
# Epoch 33/100
# 157/157 [==============================] - 3s 21ms/step - loss: 1.0190e-05 - mse: 1.0190e-05 - val_loss: 1.0420e-05 - val_mse: 1.0420e-05
# Epoch 34/100
# 157/157 [==============================] - 3s 20ms/step - loss: 9.1366e-06 - mse: 9.1366e-06 - val_loss: 9.1293e-06 - val_mse: 9.1293e-06
# Epoch 35/100
# 157/157 [==============================] - 3s 21ms/step - loss: 8.1960e-06 - mse: 8.1960e-06 - val_loss: 8.3035e-06 - val_mse: 8.3035e-06
# Epoch 36/100
# 157/157 [==============================] - 3s 20ms/step - loss: 7.3178e-06 - mse: 7.3178e-06 - val_loss: 7.4515e-06 - val_mse: 7.4515e-06
# Epoch 37/100
# 157/157 [==============================] - 3s 21ms/step - loss: 6.5406e-06 - mse: 6.5406e-06 - val_loss: 6.8392e-06 - val_mse: 6.8392e-06
# Epoch 38/100
# 157/157 [==============================] - 4s 21ms/step - loss: 5.8209e-06 - mse: 5.8209e-06 - val_loss: 6.0789e-06 - val_mse: 6.0789e-06
# Epoch 39/100
# 157/157 [==============================] - 4s 24ms/step - loss: 5.2253e-06 - mse: 5.2253e-06 - val_loss: 5.6774e-06 - val_mse: 5.6774e-06
# Epoch 40/100
# 157/157 [==============================] - 3s 20ms/step - loss: 4.7107e-06 - mse: 4.7107e-06 - val_loss: 5.0304e-06 - val_mse: 5.0304e-06
# Epoch 41/100
# 157/157 [==============================] - 3s 20ms/step - loss: 4.2835e-06 - mse: 4.2835e-06 - val_loss: 4.5011e-06 - val_mse: 4.5011e-06
# Epoch 42/100
# 157/157 [==============================] - 3s 20ms/step - loss: 3.8578e-06 - mse: 3.8578e-06 - val_loss: 4.5798e-06 - val_mse: 4.5798e-06
# Epoch 43/100
# 157/157 [==============================] - 3s 20ms/step - loss: 3.5105e-06 - mse: 3.5105e-06 - val_loss: 3.7126e-06 - val_mse: 3.7126e-06
# Epoch 44/100
# 157/157 [==============================] - 3s 20ms/step - loss: 3.2207e-06 - mse: 3.2207e-06 - val_loss: 3.5019e-06 - val_mse: 3.5019e-06
# Epoch 45/100
# 157/157 [==============================] - 4s 21ms/step - loss: 3.0716e-06 - mse: 3.0716e-06 - val_loss: 3.3320e-06 - val_mse: 3.3320e-06
# Epoch 46/100
# 157/157 [==============================] - 4s 21ms/step - loss: 2.7093e-06 - mse: 2.7093e-06 - val_loss: 2.8997e-06 - val_mse: 2.8997e-06
# Epoch 47/100
# 157/157 [==============================] - 4s 21ms/step - loss: 2.5154e-06 - mse: 2.5154e-06 - val_loss: 2.8189e-06 - val_mse: 2.8189e-06
# Epoch 48/100
# 157/157 [==============================] - 3s 20ms/step - loss: 2.4501e-06 - mse: 2.4501e-06 - val_loss: 2.5746e-06 - val_mse: 2.5746e-06
# Epoch 49/100
# 157/157 [==============================] - 3s 20ms/step - loss: 2.1904e-06 - mse: 2.1904e-06 - val_loss: 2.3144e-06 - val_mse: 2.3144e-06
# Epoch 50/100
# 157/157 [==============================] - 3s 20ms/step - loss: 2.0392e-06 - mse: 2.0392e-06 - val_loss: 2.4084e-06 - val_mse: 2.4084e-06
# Epoch 51/100
# 157/157 [==============================] - 3s 20ms/step - loss: 1.9312e-06 - mse: 1.9312e-06 - val_loss: 1.9910e-06 - val_mse: 1.9910e-06
# Epoch 52/100
# 157/157 [==============================] - 3s 20ms/step - loss: 1.8266e-06 - mse: 1.8266e-06 - val_loss: 2.0557e-06 - val_mse: 2.0557e-06
# Epoch 53/100
# 157/157 [==============================] - 4s 22ms/step - loss: 1.6583e-06 - mse: 1.6583e-06 - val_loss: 1.8033e-06 - val_mse: 1.8033e-06
# Epoch 54/100
# 157/157 [==============================] - 3s 21ms/step - loss: 1.5966e-06 - mse: 1.5966e-06 - val_loss: 1.6410e-06 - val_mse: 1.6410e-06
# Epoch 55/100
# 157/157 [==============================] - 3s 20ms/step - loss: 1.5634e-06 - mse: 1.5634e-06 - val_loss: 1.5883e-06 - val_mse: 1.5883e-06
# Epoch 56/100
# 157/157 [==============================] - 3s 20ms/step - loss: 1.4670e-06 - mse: 1.4670e-06 - val_loss: 1.7431e-06 - val_mse: 1.7431e-06
# Epoch 57/100
# 157/157 [==============================] - 3s 20ms/step - loss: 1.3314e-06 - mse: 1.3314e-06 - val_loss: 1.6000e-06 - val_mse: 1.6000e-06
# Epoch 58/100
# 157/157 [==============================] - 3s 20ms/step - loss: 1.3316e-06 - mse: 1.3316e-06 - val_loss: 1.5493e-06 - val_mse: 1.5493e-06
# Epoch 59/100
# 157/157 [==============================] - 4s 21ms/step - loss: 1.3478e-06 - mse: 1.3478e-06 - val_loss: 1.7665e-06 - val_mse: 1.7665e-06
# Epoch 60/100
# 157/157 [==============================] - 3s 21ms/step - loss: 1.1775e-06 - mse: 1.1775e-06 - val_loss: 1.8054e-06 - val_mse: 1.8054e-06
# Epoch 61/100
# 157/157 [==============================] - 3s 21ms/step - loss: 1.1810e-06 - mse: 1.1810e-06 - val_loss: 1.8140e-06 - val_mse: 1.8140e-06
# Epoch 62/100
# 157/157 [==============================] - 3s 20ms/step - loss: 1.1051e-06 - mse: 1.1051e-06 - val_loss: 1.7544e-06 - val_mse: 1.7544e-06
# Epoch 63/100
# 157/157 [==============================] - 3s 20ms/step - loss: 1.0241e-06 - mse: 1.0241e-06 - val_loss: 1.1344e-06 - val_mse: 1.1344e-06
# Epoch 64/100
# 157/157 [==============================] - 3s 21ms/step - loss: 1.0833e-06 - mse: 1.0833e-06 - val_loss: 1.6049e-06 - val_mse: 1.6049e-06
# Epoch 65/100
# 157/157 [==============================] - 4s 21ms/step - loss: 9.7763e-07 - mse: 9.7763e-07 - val_loss: 1.1537e-06 - val_mse: 1.1537e-06
# Epoch 66/100
# 157/157 [==============================] - 4s 22ms/step - loss: 9.3970e-07 - mse: 9.3970e-07 - val_loss: 9.7654e-07 - val_mse: 9.7654e-07
# Epoch 67/100
# 157/157 [==============================] - 4s 21ms/step - loss: 9.4884e-07 - mse: 9.4884e-07 - val_loss: 9.3574e-07 - val_mse: 9.3574e-07
# Epoch 68/100
# 157/157 [==============================] - 4s 23ms/step - loss: 8.2974e-07 - mse: 8.2974e-07 - val_loss: 1.0493e-06 - val_mse: 1.0493e-06
# Epoch 69/100
# 157/157 [==============================] - 4s 22ms/step - loss: 1.1182e-06 - mse: 1.1182e-06 - val_loss: 1.0009e-06 - val_mse: 1.0009e-06
# Epoch 70/100
# 157/157 [==============================] - 4s 21ms/step - loss: 7.6473e-07 - mse: 7.6473e-07 - val_loss: 1.4300e-06 - val_mse: 1.4300e-06
# Epoch 71/100
# 157/157 [==============================] - 4s 22ms/step - loss: 1.0716e-06 - mse: 1.0716e-06 - val_loss: 7.6793e-07 - val_mse: 7.6793e-07
# Epoch 72/100
# 157/157 [==============================] - 4s 21ms/step - loss: 7.3473e-07 - mse: 7.3473e-07 - val_loss: 7.9657e-07 - val_mse: 7.9657e-07
# Epoch 73/100
# 157/157 [==============================] - 4s 22ms/step - loss: 6.7139e-07 - mse: 6.7139e-07 - val_loss: 1.4649e-06 - val_mse: 1.4649e-06
# Epoch 74/100
# 157/157 [==============================] - 4s 21ms/step - loss: 7.2873e-07 - mse: 7.2873e-07 - val_loss: 1.0013e-06 - val_mse: 1.0013e-06
# Epoch 75/100
# 157/157 [==============================] - 4s 21ms/step - loss: 6.9128e-07 - mse: 6.9128e-07 - val_loss: 6.8123e-07 - val_mse: 6.8123e-07
# Epoch 76/100
# 157/157 [==============================] - 4s 21ms/step - loss: 7.2903e-07 - mse: 7.2903e-07 - val_loss: 8.3155e-07 - val_mse: 8.3155e-07
# Epoch 77/100
# 157/157 [==============================] - 3s 20ms/step - loss: 8.1196e-07 - mse: 8.1196e-07 - val_loss: 6.5416e-07 - val_mse: 6.5416e-07
# Epoch 78/100
# 157/157 [==============================] - 4s 22ms/step - loss: 5.8072e-07 - mse: 5.8072e-07 - val_loss: 8.3116e-07 - val_mse: 8.3116e-07
# Epoch 79/100
# 157/157 [==============================] - 4s 21ms/step - loss: 5.8815e-07 - mse: 5.8815e-07 - val_loss: 7.9574e-07 - val_mse: 7.9574e-07
# Epoch 80/100
# 157/157 [==============================] - 4s 22ms/step - loss: 6.7656e-07 - mse: 6.7656e-07 - val_loss: 6.7133e-07 - val_mse: 6.7133e-07
# Epoch 81/100
# 157/157 [==============================] - 4s 21ms/step - loss: 5.9305e-07 - mse: 5.9305e-07 - val_loss: 6.6089e-07 - val_mse: 6.6089e-07
# Epoch 82/100
# 157/157 [==============================] - 3s 21ms/step - loss: 9.1599e-07 - mse: 9.1599e-07 - val_loss: 5.6159e-07 - val_mse: 5.6159e-07
# Epoch 83/100
# 157/157 [==============================] - 4s 22ms/step - loss: 5.3407e-07 - mse: 5.3407e-07 - val_loss: 6.3947e-07 - val_mse: 6.3947e-07
# Epoch 84/100
# 157/157 [==============================] - 3s 21ms/step - loss: 5.1112e-07 - mse: 5.1112e-07 - val_loss: 9.0291e-07 - val_mse: 9.0291e-07
# Epoch 85/100
# 157/157 [==============================] - 3s 20ms/step - loss: 6.4281e-07 - mse: 6.4281e-07 - val_loss: 5.5623e-07 - val_mse: 5.5623e-07
# Epoch 86/100
# 157/157 [==============================] - 4s 22ms/step - loss: 7.2154e-07 - mse: 7.2154e-07 - val_loss: 8.8019e-07 - val_mse: 8.8019e-07
# Epoch 87/100
# 157/157 [==============================] - 3s 19ms/step - loss: 5.0561e-07 - mse: 5.0561e-07 - val_loss: 1.2351e-06 - val_mse: 1.2351e-06
# Epoch 88/100
# 157/157 [==============================] - 4s 22ms/step - loss: 4.9285e-07 - mse: 4.9285e-07 - val_loss: 5.0590e-07 - val_mse: 5.0590e-07
# Epoch 89/100
# 157/157 [==============================] - 4s 21ms/step - loss: 6.9022e-07 - mse: 6.9022e-07 - val_loss: 5.4121e-07 - val_mse: 5.4121e-07
# Epoch 90/100
# 157/157 [==============================] - 4s 21ms/step - loss: 6.1039e-07 - mse: 6.1039e-07 - val_loss: 4.3720e-07 - val_mse: 4.3720e-07
# Epoch 91/100
# 157/157 [==============================] - 4s 21ms/step - loss: 7.2838e-07 - mse: 7.2839e-07 - val_loss: 4.1127e-07 - val_mse: 4.1127e-07
# Epoch 92/100
# 157/157 [==============================] - 4s 22ms/step - loss: 3.8651e-07 - mse: 3.8651e-07 - val_loss: 5.1621e-07 - val_mse: 5.1621e-07
# Epoch 93/100
# 157/157 [==============================] - 4s 21ms/step - loss: 4.9377e-07 - mse: 4.9377e-07 - val_loss: 4.8764e-07 - val_mse: 4.8764e-07
# Epoch 94/100
# 157/157 [==============================] - 4s 21ms/step - loss: 4.6375e-07 - mse: 4.6375e-07 - val_loss: 4.9294e-07 - val_mse: 4.9294e-07
# Epoch 95/100
# 157/157 [==============================] - 4s 22ms/step - loss: 4.4000e-07 - mse: 4.4000e-07 - val_loss: 7.3676e-07 - val_mse: 7.3676e-07
# Epoch 96/100
# 157/157 [==============================] - 4s 24ms/step - loss: 5.8505e-07 - mse: 5.8505e-07 - val_loss: 3.8407e-07 - val_mse: 3.8407e-07
# Epoch 97/100
# 157/157 [==============================] - 4s 21ms/step - loss: 4.8794e-07 - mse: 4.8794e-07 - val_loss: 4.8950e-07 - val_mse: 4.8950e-07
# Epoch 98/100
# 157/157 [==============================] - 4s 21ms/step - loss: 3.9032e-07 - mse: 3.9032e-07 - val_loss: 4.0153e-07 - val_mse: 4.0153e-07
# Epoch 99/100
# 157/157 [==============================] - 4s 22ms/step - loss: 5.4906e-07 - mse: 5.4906e-07 - val_loss: 4.9554e-07 - val_mse: 4.9554e-07
# Epoch 100/100
# 157/157 [==============================] - 4s 22ms/step - loss: 3.6775e-07 - mse: 3.6775e-07 - val_loss: 3.8127e-07 - val_mse: 3.8127e-07

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train loss')
plt.plot(history.history['val_loss'], label='Validation loss')

# Adding labels and title
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.title('Training and Validation Loss Curves')
plt.yscale("log")
plt.legend()
plt.show()

# %% [markdown]
# ## Prediction on the test data in closed-loop
#
# We compare two different predictions on the test data:
# #### 1. Short-term prediction:
# - This demonstrates how long the short-term prediction of the LSTM corresponds to the reference solution. Because the systems is chaotic, any two close trajectories will seperate after a given time. We expect a prediction of at least 1 Lyapunov time.
#
# #### 2. Long-term prediction:
# - This demonstrates how statistical prediction of the LSTM and allows us to understand if the network reproduces the long-term behaviour (sometimes referred as climate) of the chaotic system.

# %%
# take a random time window from the test data
N_start = np.random.randint(len(U_test)-10000)
single_window = np.reshape(U_test[N_start:N_start+window_size, :], newshape=(1, window_size, 3))
prediction = tf_lstm.closed_loop_prediction(tf.convert_to_tensor(single_window), prediction_length=1000)

# %%
N_plot = min(10 * N_lyap,prediction.shape[0], U_rk4[N_start:, :].shape[0])
# Define time steps
time_steps = np.arange(0, N_plot * dt, dt) / t_lyap
prediction_plot = prediction
reference_plot = U_test[N_start:N_start+prediction.shape[0], :] 
# Create a figure with three subplots
fig, axes = plt.subplots(3, 1)

# Plot U_test for the first feature
axes[0].plot(time_steps[:N_plot], reference_plot[:N_plot, 0], color='black', label='Reference')
axes[0].plot(time_steps[:N_plot], prediction_plot[:N_plot, 0], color='red', linestyle='dashed', label=' Prediction')
axes[0].set_ylabel("x")
axes[0].set_xlabel("LT")

# Plot U_test for the second feature
axes[1].plot(time_steps, reference_plot[:N_plot, 1], color='black', label='Reference')
axes[1].plot(time_steps, prediction_plot[:N_plot, 1], color='red', linestyle='dashed', label=' Prediction')
axes[1].set_ylabel("y")
axes[1].set_xlabel("LT")
axes[1].legend(loc='upper left', bbox_to_anchor=(1, 1))

# Plot prediction and U_test for the third feature
axes[2].plot(time_steps[:N_plot], reference_plot[:N_plot, 2], color='black', label='Reference')
axes[2].plot(time_steps[:N_plot], prediction_plot[:N_plot, 2], color='red', linestyle='dashed', label='LSTM Prediction')
axes[2].set_ylabel("z")
axes[2].set_xlabel("LT")

# Add a title for the entire figure
fig.suptitle("Comparison of LSTM Prediction and Reference")
# Adjust layout for better spacing
plt.tight_layout()
# Show the plot
plt.show()

# %%
def stats_lorenz63(prediction_length, single_window):
    prediction = tf_lstm.closed_loop_prediction(single_window, prediction_length=prediction_length)
    Ys_t = prediction

        
    # Calculate the integral of the kde between 10 and 20:
    xmin, xmax = -1,1 
    n_bins = 50
    x = np.linspace(xmin,xmax,n_bins)
    
    fig, axs = plt.subplots(1,3)
    
    fig.suptitle('Probability Density Function (PDF)')

    fig.set_figheight(4)
    fig.set_figwidth(16)

    for i in range(dim):
        signal = U_test[:prediction_length,i]
        signal_p  = Ys_t[:prediction_length,i] #predicted closed loop
        
        kde = stats.gaussian_kde(signal)
        kde_p = stats.gaussian_kde(signal_p)
            
        axs[i].plot(x,kde(x),color='black', label='Reference')
        axs[i].plot(x,kde_p(x), color='red', linestyle='dashed', label='LSTM Prediction')
        axs[i].set_ylabel('PDF')

    axs[0].set_xlabel('$x$')
    axs[1].set_xlabel('$y$')
    axs[2].set_xlabel('$z$')
    plt.legend()    
    
    return(Ys_t)

# %%
prediction_length = 50*N_lyap # How many lyapunov times to generate for statistical predictions
U_pred_lstm = stats_lorenz63(prediction_length, single_window)
plt.show()

# %%
fig = plt.figure(figsize=(12, 5))

# First subplot for U_rk4
ax1 = fig.add_subplot(121, projection='3d')
fig.subplots_adjust(left=0, right=0.55, bottom=0, top=1)

# Make the line multi-coloured by plotting it in segments of length s which
# change in colour across the whole time series.
n = len(U_rk4[:10000])
s = 100
cmap = plt.cm.winter  # winter

for i in range(0, n - s, s):
    ax1.plot(U_rk4[i:i+s+1, 0], U_rk4[i:i+s+1, 1], U_rk4[i:i+s+1, 2], color=cmap(i/n), alpha=0.4)

ax1.set_title('Reference Attractor ')

# Second subplot for U_pred_lstm
ax2 = fig.add_subplot(122, projection='3d', sharex=ax1, sharey=ax1, sharez=ax1)
fig.subplots_adjust(left=0.55, right=1, bottom=0, top=1)

# Make the line multi-coloured by plotting it in segments of length s which
# change in colour across the whole time series.
for i in range(0, n - s, s):
    ax2.plot(U_pred_lstm[i:i+s+1, 0], U_pred_lstm[i:i+s+1, 1], U_pred_lstm[i:i+s+1, 2], color=cmap(i/n), alpha=0.4)

ax2.set_title('LSTM Attractor')

plt.show()

# %%
LEs_lstm = compute_lyapunov_exp_lstm(single_window, tf_lstm, 100*N_lyap, dim=3)
# Out:
# Finished on Transient
# Inside closed loop i = 10000, Time: 68.86321830749512
# Lyapunov exponents: [ 8.96678363e-01  1.86991735e-03 -1.62886419e+01]
# Final Lyapunov exponents: [ 8.93305135e-01 -8.81566088e-03 -1.63131168e+01]

# %%
plt.plot(np.arange(len(LEs_lstm)*dt, step=dt), LEs_lstm)
plt.title("Covergence of LSTM Lyapunov exponents")
plt.ylabel("LEs")
plt.xlabel(r"$t_p$")
# Out:
# Text(0.5, 0, '$N_{lyap}$')
