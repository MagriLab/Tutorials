# %% [markdown]
# # LSTMs for Chaotic Dynamics
#
# ### Authors: Elise Özalp (elise.ozalp@imperial.ac.uk), Luca Magri (luca.magri@imperial.ac.uk)
#
# ## Introduction
#
# This notebook explores the application of Long Short-Term Memory (LSTM) networks in learning chaotic dynamics and their stability properties, focusing on the Lorenz-63 system. Chaotic systems like Lorenz-63 exhibit complex behavior, making them challenging for modeling. We discuss the training process, model evaluation, and the interpretability of LSTM predictions in the context of chaotic systems. The results obtained provide valuable insights into the potential of deep learning models for understanding and predicting chaotic behavior.
#
#
# ## Lorenz-63 System
#
# The Lorenz-63 system is a set of ordinary differential equations that describe a simplified atmospheric convection model. It is a classic example of a chaotic system, characterized by sensitive dependence on initial conditions. In this notebook, we delve into the dynamics of the Lorenz-63 system and discuss the challenges of capturing its chaotic nature.
#
# ## LSTMs and Chaotic Dynamics
#
# Long Short-Term Memory networks, a type of recurrent neural network (RNN), have shown promise in capturing intricate temporal dependencies in sequential data. We explore how LSTMs can be applied to learn and predict the chaotic behavior inherent in systems like Lorenz-63. Through this analysis, we aim to gain insights into the capabilities and limitations of LSTMs in handling chaotic dynamics.
#
# ## Learning Chaotic Dynamics from Data
#
# The core focus of this notebook is on utilizing LSTMs to learn chaotic dynamics from data generated by the Lorenz-63 system.
# Feel free to adapt and expand upon this structure to suit the specific details and findings of your analysis.

# %%
import matplotlib.pyplot as plt
import numpy as np
import time
import scipy
import einops
import scipy.stats as stats 
from mpl_toolkits.mplot3d import Axes3D
import os 
import logging
logging.getLogger('tensorflow').setLevel(logging.ERROR)
os.environ["KMP_AFFINITY"] = "noverbose"
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
tf.config.set_visible_devices([], 'GPU')
tf.autograph.set_verbosity(3)
from dynamicalsystems.tools import solve_ode_LEs
from lstm.lstm import TensorFlowLSTM
from lstm.lyapunov_tools import compute_lyapunov_exp_lstm

# %% [markdown]
# #
#
# ## Lorenz-63 System
#
# The Lorenz-63 system is a set of ordinary differential equations that describe a simplified atmospheric convection model. It is a classic example of a chaotic system, characterized by sensitive dependence on initial conditions. In this notebook, we delve into the dynamics of the Lorenz-63 system and discuss the challenges of capturing its chaotic nature.
#
# The system is given by
#
# \begin{align*}
# \frac{dx}{dt} &= \sigma \cdot (y - x) \\
# \frac{dy}{dt} &= x \cdot (\rho - z) - y \\
# \frac{dz}{dt} &= x \cdot y - \beta \cdot z
# \end{align*}
#
#
# where  x, y, z are the state variables and $\beta$, $\rho $, and  $\sigma $ are system parameters. For $\beta = \frac{8}{3}, \rho =28, \sigma = 10$, the system exhibits chaotic behaviour. We select the initial condition $\begin{bmatrix} x(0); y(0); z(0) \end{bmatrix} = \begin{bmatrix} 0; 1; 1 \end{bmatrix}$. For this system, the largest Lyapunov exponent is given by $\lambda\approx 0.9$.
#
# ### Generating the data:
# We solve the system using RK45, remove an initial transient and then normalize the input between $\begin{bmatrix}-1, 1\end{bmatrix}$ (for better training).

# %%
def lorenz63(u, params):
    beta, rho, sigma = params
    x, y, z = u
    return np.array([sigma*(y-x), x*(rho-z)-y, x*y-beta*z])

def l63jac(u, params):
    beta, rho, sigma = params # Unpack the constants vector
    x, y, z          = u  # Unpack the state vector

    #Jacobian
    J = np.array([[-sigma, sigma,     0],
                  [ rho-z,    -1,    -x],
                  [     y,     x, -beta]])
    return J

# %%
dim = 3
params = [2.667, 28, 10]  # beta, rho, sigma
u0 = np.array([0.0, 1.0, 1.0])  # initial condition

dt = 0.01  # time step
t_lyap = 0.9**(-1)  # Lyapunov time

N_lyap = int(t_lyap/dt)
N_trans = 2000  # initial transient to discard
N_total = 500*N_lyap + N_trans
time_array, U_rk4, LEs = solve_ode_LEs(N_total, N_trans, dt, u0, lorenz63, l63jac, params,  dim=3)
time_array = time_array[N_trans:]
U_rk4 = U_rk4[N_trans:].astype(np.float32)
U_rk4 = U_rk4/np.max(U_rk4, axis=0)  # remove the initial transient
time_array_lyap = np.arange(0, len(time_array), step=dt)/0.09
print(f"Shape of solution generated with RK45: {U_rk4.shape}")
# Out:
# Number of timesteps 57500
# Number of timesteps in test 55500
# Lyapunov Exponents: [ 9.02006892e-01 -6.34432322e-05 -1.45688415e+01]
# Shape of solution generated with RK45: (55501, 3)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
fig.subplots_adjust(left=0, right=1, bottom=0, top=1)

# Make the line multi-coloured by plotting it in segments of length s which
# change in colour across the whole time series.
n = len(U_rk4[:10000])
s = 100
cmap = plt.cm.winter  # winter
cmap_2 = plt.cm.autumn  # autumn

for i in range(0, n - s, s):
    ax.plot(U_rk4[i:i+s+1, 0], U_rk4[i:i+s+1, 1], U_rk4[i:i+s+1, 2], color=cmap(i/n), alpha=0.4)

plt.show()

# %% [markdown]
# #
#
# ## Preparing the data for training
#
#
# #### 1. Splitting Data
# - Divide the dataset into three sets: training, testing, and validation data.
#
# #### 2. Time Window for LSTM
# - The LSTM takes data of the following input shape (batch size, window size, dimension of observations). The window size refers to the number of consecutive time steps.

# %%
def split_data(U, train_size, valid_size, test_size):
    return U[:train_size], U[train_size: train_size + valid_size],  U[train_size + valid_size : train_size + valid_size+test_size]

def create_windows(series, window_size, batch_size, shuffle_buffer, shuffle_window=10):
    n = series.shape[1]
    m = series.shape[0]
    dataset = tf.data.Dataset.from_tensor_slices(series)
    dataset = dataset.window(size=window_size + 1, shift=1, drop_remainder=True)
    dataset = dataset.shuffle(m * shuffle_window)
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))
    dataset = dataset.shuffle(shuffle_buffer).map(
        lambda window: (window[:-1], window[1:])
    )
    dataset = dataset.padded_batch(batch_size, padded_shapes=([None, n], [None, n]))
    return  dataset

# %%
# set sizes
train_size = 20000
valid_size = 5000
test_size = 25000

U_train, U_valid, U_test = split_data(U_rk4, train_size, valid_size, test_size)
time_train, time_valid, time_test = split_data(time_array_lyap, train_size, valid_size, test_size)

fig, axs = plt.subplots(3, sharex=True, sharey=True)
axs[0].plot(time_train, U_train[:, 0], time_valid, U_valid[:, 0], time_test, U_test[:, 0])
axs[1].plot(time_train, U_train[:, 1], time_valid, U_valid[:, 1], time_test, U_test[:, 1])
axs[0].set_ylabel('x')
axs[1].set_ylabel('y')
axs[2].plot(time_train, U_train[:, 2], label='Training Data')
axs[2].plot(time_valid, U_valid[:, 2], label='Validation Data')
axs[2].plot(time_test, U_test[:, 2], label='Test Data')
axs[2].set_ylabel('z')
axs[2].set_xlabel('Lyapunov Time')
# ax3.set_xlim(0,1)
axs[2].legend(loc='center left', bbox_to_anchor=(1, 1.5))
plt.show()

# %%
batch_size = 128  # Choose your desired batch size
window_size = 10  # Choose your desired window size
train_dataset = create_windows(U_train, window_size=10, batch_size=128, shuffle_buffer=1)

valid_dataset = create_windows(U_valid, window_size=10, batch_size=128, shuffle_buffer=1)

for input, label in train_dataset.take(1):
    print(f"LSTM takes inputs: (batch size, window size, dimension of observations)")
    print(f"Input shape {input.shape} \nLabel shape {label.shape}")
# Out:
# LSTM takes inputs: (batch size, window size, dimension of observations)
# Input shape (128, 10, 3)
# Label shape (128, 10, 3)

# %% [markdown]
# # LSTMs
#
# - LSTMs feature three key gates—input, forget, and output gates—that control the flow of information within the cell.
# - Information of previous cells is kept in both the hidden and cell states.
#   - The hidden state encapsulates long-term information, while the cell state retains short-term information.
#
# <p align="center">
#   <img src="Images/lstm_cell.png" alt="LSTM cell" width="30%"/>
# </p>

# %% [markdown]
# ## Open-Loop Mode
#
# The network works in an open-loop configuration during training and validation with the output at each time step depending on current and previous inputs within the time window, and the LSTM’s states are reset to zero at the start of each input sequence.
#
# <p align="center">
#   <img src="Images/lstm_open_loop.png" alt="LSTM Open Loop" width="30%"/>
# </p>
#
#
# ## Closed-Loop Mode
#
# After training, the network is evaluated on test data with fixed weights and biases, operating in a closed-loop configuration. After a warm-up of one
# time window, the network can make long-term predictions in closed loop mode, even if no data is available, and the states of the LSTM are retained across time steps. The network predicts the next time step, and the prediction is used as an input for the next time step, which allows the autonomous evolution of the LSTM.
#
# <p align="center">
#   <img src="Images/lstm_closed_loop.png" alt="LSTM Closed Loop" width="30%"/>
# </p>

# %%
tf_lstm = TensorFlowLSTM(hidden_size=30, window_size=window_size, observation_dimension=3)
tf_lstm(input)
tf_lstm.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  LSTM_1 (LSTM)               (128, 10, 30)             4080
#
#  DenseLayer (Dense)          (128, 10, 3)              93
#
# =================================================================
# Total params: 4,173
# Trainable params: 4,173
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = tf_lstm.model.fit(train_dataset, validation_data = valid_dataset, epochs = 100)
# Out:
# Epoch 1/100
# 157/157 [==============================] - 7s 27ms/step - loss: 0.0391 - mse: 0.0391 - val_loss: 0.0144 - val_mse: 0.0144
# Epoch 2/100
# 157/157 [==============================] - 3s 20ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 3/100
# 157/157 [==============================] - 3s 21ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 4/100
# 157/157 [==============================] - 3s 21ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 5/100
# 157/157 [==============================] - 3s 21ms/step - loss: 9.3540e-04 - mse: 9.3540e-04 - val_loss: 7.2822e-04 - val_mse: 7.2822e-04
# Epoch 6/100
# 157/157 [==============================] - 4s 21ms/step - loss: 6.1095e-04 - mse: 6.1095e-04 - val_loss: 4.9874e-04 - val_mse: 4.9874e-04
# Epoch 7/100
# 157/157 [==============================] - 3s 21ms/step - loss: 4.4295e-04 - mse: 4.4295e-04 - val_loss: 3.6739e-04 - val_mse: 3.6739e-04
# Epoch 8/100
# 157/157 [==============================] - 3s 21ms/step - loss: 3.3550e-04 - mse: 3.3550e-04 - val_loss: 2.7975e-04 - val_mse: 2.7975e-04
# Epoch 9/100
# 157/157 [==============================] - 3s 20ms/step - loss: 2.5951e-04 - mse: 2.5951e-04 - val_loss: 2.1651e-04 - val_mse: 2.1651e-04
# Epoch 10/100
# 157/157 [==============================] - 4s 21ms/step - loss: 2.0277e-04 - mse: 2.0277e-04 - val_loss: 1.7039e-04 - val_mse: 1.7039e-04
# Epoch 11/100
# 157/157 [==============================] - 3s 21ms/step - loss: 1.5928e-04 - mse: 1.5928e-04 - val_loss: 1.3419e-04 - val_mse: 1.3419e-04
# Epoch 12/100
# 157/157 [==============================] - 3s 21ms/step - loss: 1.2575e-04 - mse: 1.2575e-04 - val_loss: 1.0637e-04 - val_mse: 1.0637e-04
# Epoch 13/100
# 157/157 [==============================] - 3s 20ms/step - loss: 9.9775e-05 - mse: 9.9775e-05 - val_loss: 8.5106e-05 - val_mse: 8.5106e-05
# Epoch 14/100
# 157/157 [==============================] - 4s 21ms/step - loss: 7.9813e-05 - mse: 7.9813e-05 - val_loss: 6.8828e-05 - val_mse: 6.8828e-05
# Epoch 15/100
# 157/157 [==============================] - 3s 21ms/step - loss: 6.4609e-05 - mse: 6.4609e-05 - val_loss: 5.6246e-05 - val_mse: 5.6246e-05
# Epoch 16/100
# 157/157 [==============================] - 4s 22ms/step - loss: 5.3049e-05 - mse: 5.3049e-05 - val_loss: 4.6834e-05 - val_mse: 4.6834e-05
# Epoch 17/100
# 157/157 [==============================] - 3s 21ms/step - loss: 4.4285e-05 - mse: 4.4285e-05 - val_loss: 3.9581e-05 - val_mse: 3.9581e-05
# Epoch 18/100
# 157/157 [==============================] - 4s 21ms/step - loss: 3.7600e-05 - mse: 3.7600e-05 - val_loss: 3.4056e-05 - val_mse: 3.4056e-05
# Epoch 19/100
# 157/157 [==============================] - 3s 21ms/step - loss: 3.2478e-05 - mse: 3.2478e-05 - val_loss: 2.9991e-05 - val_mse: 2.9991e-05
# Epoch 20/100
# 157/157 [==============================] - 3s 21ms/step - loss: 2.8544e-05 - mse: 2.8544e-05 - val_loss: 2.6369e-05 - val_mse: 2.6369e-05
# Epoch 21/100
# 157/157 [==============================] - 4s 21ms/step - loss: 2.5437e-05 - mse: 2.5437e-05 - val_loss: 2.3742e-05 - val_mse: 2.3742e-05
# Epoch 22/100
# 157/157 [==============================] - 4s 22ms/step - loss: 2.2969e-05 - mse: 2.2969e-05 - val_loss: 2.1614e-05 - val_mse: 2.1614e-05
# Epoch 23/100
# 157/157 [==============================] - 3s 21ms/step - loss: 2.0981e-05 - mse: 2.0981e-05 - val_loss: 1.9895e-05 - val_mse: 1.9895e-05
# Epoch 24/100
# 157/157 [==============================] - 4s 21ms/step - loss: 1.9320e-05 - mse: 1.9320e-05 - val_loss: 1.8326e-05 - val_mse: 1.8326e-05
# Epoch 25/100
# 157/157 [==============================] - 3s 20ms/step - loss: 1.7900e-05 - mse: 1.7900e-05 - val_loss: 1.7067e-05 - val_mse: 1.7067e-05
# Epoch 26/100
# 157/157 [==============================] - 4s 22ms/step - loss: 1.6654e-05 - mse: 1.6654e-05 - val_loss: 1.5896e-05 - val_mse: 1.5896e-05
# Epoch 27/100
# 157/157 [==============================] - 4s 22ms/step - loss: 1.5492e-05 - mse: 1.5492e-05 - val_loss: 1.4787e-05 - val_mse: 1.4787e-05
# Epoch 28/100
# 157/157 [==============================] - 4s 22ms/step - loss: 1.4421e-05 - mse: 1.4421e-05 - val_loss: 1.3820e-05 - val_mse: 1.3820e-05
# Epoch 29/100
# 157/157 [==============================] - 3s 20ms/step - loss: 1.3425e-05 - mse: 1.3425e-05 - val_loss: 1.3025e-05 - val_mse: 1.3025e-05
# Epoch 30/100
# 157/157 [==============================] - 3s 20ms/step - loss: 1.2457e-05 - mse: 1.2457e-05 - val_loss: 1.2028e-05 - val_mse: 1.2028e-05
# Epoch 31/100
# 157/157 [==============================] - 3s 21ms/step - loss: 1.1531e-05 - mse: 1.1531e-05 - val_loss: 1.1107e-05 - val_mse: 1.1107e-05
# Epoch 32/100
# 157/157 [==============================] - 3s 21ms/step - loss: 1.0651e-05 - mse: 1.0651e-05 - val_loss: 1.0256e-05 - val_mse: 1.0256e-05
# Epoch 33/100
# 157/157 [==============================] - 3s 20ms/step - loss: 9.8089e-06 - mse: 9.8089e-06 - val_loss: 9.4742e-06 - val_mse: 9.4742e-06
# Epoch 34/100
# 157/157 [==============================] - 4s 22ms/step - loss: 9.0053e-06 - mse: 9.0053e-06 - val_loss: 8.7785e-06 - val_mse: 8.7785e-06
# Epoch 35/100
# 157/157 [==============================] - 4s 22ms/step - loss: 8.2567e-06 - mse: 8.2567e-06 - val_loss: 8.1391e-06 - val_mse: 8.1391e-06
# Epoch 36/100
# 157/157 [==============================] - 3s 21ms/step - loss: 7.5371e-06 - mse: 7.5371e-06 - val_loss: 7.4386e-06 - val_mse: 7.4386e-06
# Epoch 37/100
# 157/157 [==============================] - 4s 22ms/step - loss: 6.8775e-06 - mse: 6.8775e-06 - val_loss: 6.8067e-06 - val_mse: 6.8067e-06
# Epoch 38/100
# 157/157 [==============================] - 4s 22ms/step - loss: 6.2760e-06 - mse: 6.2760e-06 - val_loss: 6.1546e-06 - val_mse: 6.1546e-06
# Epoch 39/100
# 157/157 [==============================] - 3s 21ms/step - loss: 5.7168e-06 - mse: 5.7168e-06 - val_loss: 5.6455e-06 - val_mse: 5.6455e-06
# Epoch 40/100
# 157/157 [==============================] - 3s 20ms/step - loss: 5.2514e-06 - mse: 5.2514e-06 - val_loss: 5.2228e-06 - val_mse: 5.2228e-06
# Epoch 41/100
# 157/157 [==============================] - 3s 20ms/step - loss: 4.8001e-06 - mse: 4.8001e-06 - val_loss: 4.7413e-06 - val_mse: 4.7413e-06
# Epoch 42/100
# 157/157 [==============================] - 4s 21ms/step - loss: 4.3687e-06 - mse: 4.3687e-06 - val_loss: 4.4056e-06 - val_mse: 4.4056e-06
# Epoch 43/100
# 157/157 [==============================] - 4s 21ms/step - loss: 4.0419e-06 - mse: 4.0419e-06 - val_loss: 4.3429e-06 - val_mse: 4.3429e-06
# Epoch 44/100
# 157/157 [==============================] - 3s 21ms/step - loss: 3.8168e-06 - mse: 3.8168e-06 - val_loss: 4.1033e-06 - val_mse: 4.1033e-06
# Epoch 45/100
# 157/157 [==============================] - 3s 20ms/step - loss: 3.4795e-06 - mse: 3.4795e-06 - val_loss: 3.8781e-06 - val_mse: 3.8781e-06
# Epoch 46/100
# 157/157 [==============================] - 4s 21ms/step - loss: 3.2455e-06 - mse: 3.2455e-06 - val_loss: 3.3698e-06 - val_mse: 3.3698e-06
# Epoch 47/100
# 157/157 [==============================] - 4s 21ms/step - loss: 3.0190e-06 - mse: 3.0190e-06 - val_loss: 3.0630e-06 - val_mse: 3.0630e-06
# Epoch 48/100
# 157/157 [==============================] - 3s 21ms/step - loss: 2.9408e-06 - mse: 2.9408e-06 - val_loss: 2.9106e-06 - val_mse: 2.9106e-06
# Epoch 49/100
# 157/157 [==============================] - 3s 20ms/step - loss: 2.5872e-06 - mse: 2.5872e-06 - val_loss: 2.7170e-06 - val_mse: 2.7170e-06
# Epoch 50/100
# 157/157 [==============================] - 4s 22ms/step - loss: 2.4360e-06 - mse: 2.4360e-06 - val_loss: 2.4222e-06 - val_mse: 2.4222e-06
# Epoch 51/100
# 157/157 [==============================] - 3s 21ms/step - loss: 2.2966e-06 - mse: 2.2966e-06 - val_loss: 2.4515e-06 - val_mse: 2.4515e-06
# Epoch 52/100
# 157/157 [==============================] - 4s 21ms/step - loss: 2.2280e-06 - mse: 2.2280e-06 - val_loss: 2.3292e-06 - val_mse: 2.3292e-06
# Epoch 53/100
# 157/157 [==============================] - 3s 21ms/step - loss: 2.1013e-06 - mse: 2.1013e-06 - val_loss: 2.0717e-06 - val_mse: 2.0717e-06
# Epoch 54/100
# 157/157 [==============================] - 4s 21ms/step - loss: 1.9624e-06 - mse: 1.9624e-06 - val_loss: 1.9524e-06 - val_mse: 1.9524e-06
# Epoch 55/100
# 157/157 [==============================] - 4s 22ms/step - loss: 1.8820e-06 - mse: 1.8820e-06 - val_loss: 1.9653e-06 - val_mse: 1.9653e-06
# Epoch 56/100
# 157/157 [==============================] - 4s 22ms/step - loss: 1.7984e-06 - mse: 1.7984e-06 - val_loss: 2.1787e-06 - val_mse: 2.1787e-06
# Epoch 57/100
# 157/157 [==============================] - 3s 20ms/step - loss: 1.6419e-06 - mse: 1.6419e-06 - val_loss: 1.7537e-06 - val_mse: 1.7537e-06
# Epoch 58/100
# 157/157 [==============================] - 4s 21ms/step - loss: 1.4631e-06 - mse: 1.4631e-06 - val_loss: 1.5443e-06 - val_mse: 1.5443e-06
# Epoch 59/100
# 157/157 [==============================] - 4s 21ms/step - loss: 1.4917e-06 - mse: 1.4917e-06 - val_loss: 1.5049e-06 - val_mse: 1.5049e-06
# Epoch 60/100
# 157/157 [==============================] - 4s 21ms/step - loss: 1.5508e-06 - mse: 1.5508e-06 - val_loss: 1.4800e-06 - val_mse: 1.4800e-06
# Epoch 61/100
# 157/157 [==============================] - 4s 21ms/step - loss: 1.2489e-06 - mse: 1.2489e-06 - val_loss: 1.2931e-06 - val_mse: 1.2931e-06
# Epoch 62/100
# 157/157 [==============================] - 4s 21ms/step - loss: 1.1809e-06 - mse: 1.1809e-06 - val_loss: 2.9855e-06 - val_mse: 2.9855e-06
# Epoch 63/100
# 157/157 [==============================] - 4s 22ms/step - loss: 1.2666e-06 - mse: 1.2666e-06 - val_loss: 1.2719e-06 - val_mse: 1.2719e-06
# Epoch 64/100
# 157/157 [==============================] - 3s 21ms/step - loss: 1.1196e-06 - mse: 1.1196e-06 - val_loss: 1.8412e-06 - val_mse: 1.8412e-06
# Epoch 65/100
# 157/157 [==============================] - 4s 21ms/step - loss: 1.0874e-06 - mse: 1.0874e-06 - val_loss: 1.1533e-06 - val_mse: 1.1533e-06
# Epoch 66/100
# 157/157 [==============================] - 3s 21ms/step - loss: 1.1359e-06 - mse: 1.1359e-06 - val_loss: 1.0621e-06 - val_mse: 1.0621e-06
# Epoch 67/100
# 157/157 [==============================] - 3s 21ms/step - loss: 9.6983e-07 - mse: 9.6983e-07 - val_loss: 9.9687e-07 - val_mse: 9.9687e-07
# Epoch 68/100
# 157/157 [==============================] - 3s 20ms/step - loss: 9.8325e-07 - mse: 9.8325e-07 - val_loss: 1.1465e-06 - val_mse: 1.1465e-06
# Epoch 69/100
# 157/157 [==============================] - 4s 21ms/step - loss: 8.3571e-07 - mse: 8.3571e-07 - val_loss: 9.2836e-07 - val_mse: 9.2836e-07
# Epoch 70/100
# 157/157 [==============================] - 4s 21ms/step - loss: 1.0088e-06 - mse: 1.0088e-06 - val_loss: 1.1795e-06 - val_mse: 1.1795e-06
# Epoch 71/100
# 157/157 [==============================] - 3s 21ms/step - loss: 7.9969e-07 - mse: 7.9969e-07 - val_loss: 9.5602e-07 - val_mse: 9.5602e-07
# Epoch 72/100
# 157/157 [==============================] - 3s 21ms/step - loss: 8.6451e-07 - mse: 8.6451e-07 - val_loss: 7.4835e-07 - val_mse: 7.4835e-07
# Epoch 73/100
# 157/157 [==============================] - 3s 21ms/step - loss: 7.3090e-07 - mse: 7.3090e-07 - val_loss: 6.4440e-07 - val_mse: 6.4440e-07
# Epoch 74/100
# 157/157 [==============================] - 3s 21ms/step - loss: 1.0253e-06 - mse: 1.0253e-06 - val_loss: 1.3483e-06 - val_mse: 1.3483e-06
# Epoch 75/100
# 157/157 [==============================] - 3s 20ms/step - loss: 6.3098e-07 - mse: 6.3098e-07 - val_loss: 7.7393e-07 - val_mse: 7.7393e-07
# Epoch 76/100
# 157/157 [==============================] - 4s 21ms/step - loss: 5.8238e-07 - mse: 5.8238e-07 - val_loss: 6.3739e-07 - val_mse: 6.3739e-07
# Epoch 77/100
# 157/157 [==============================] - 4s 21ms/step - loss: 7.4602e-07 - mse: 7.4602e-07 - val_loss: 7.6055e-07 - val_mse: 7.6055e-07
# Epoch 78/100
# 157/157 [==============================] - 4s 21ms/step - loss: 5.7782e-07 - mse: 5.7782e-07 - val_loss: 5.6474e-07 - val_mse: 5.6474e-07
# Epoch 79/100
# 157/157 [==============================] - 4s 22ms/step - loss: 6.6884e-07 - mse: 6.6884e-07 - val_loss: 6.3378e-07 - val_mse: 6.3378e-07
# Epoch 80/100
# 157/157 [==============================] - 3s 21ms/step - loss: 6.0379e-07 - mse: 6.0379e-07 - val_loss: 5.6715e-07 - val_mse: 5.6715e-07
# Epoch 81/100
# 157/157 [==============================] - 4s 23ms/step - loss: 6.0946e-07 - mse: 6.0946e-07 - val_loss: 5.9761e-07 - val_mse: 5.9761e-07
# Epoch 82/100
# 157/157 [==============================] - 3s 21ms/step - loss: 6.2079e-07 - mse: 6.2079e-07 - val_loss: 6.7130e-07 - val_mse: 6.7130e-07
# Epoch 83/100
# 157/157 [==============================] - 4s 22ms/step - loss: 4.7716e-07 - mse: 4.7716e-07 - val_loss: 5.2278e-07 - val_mse: 5.2278e-07
# Epoch 84/100
# 157/157 [==============================] - 3s 21ms/step - loss: 5.4917e-07 - mse: 5.4917e-07 - val_loss: 7.9089e-07 - val_mse: 7.9089e-07
# Epoch 85/100
# 157/157 [==============================] - 3s 21ms/step - loss: 6.7089e-07 - mse: 6.7089e-07 - val_loss: 5.7597e-07 - val_mse: 5.7597e-07
# Epoch 86/100
# 157/157 [==============================] - 3s 20ms/step - loss: 6.4067e-07 - mse: 6.4067e-07 - val_loss: 7.3324e-07 - val_mse: 7.3324e-07
# Epoch 87/100
# 157/157 [==============================] - 3s 21ms/step - loss: 4.2951e-07 - mse: 4.2951e-07 - val_loss: 4.8585e-07 - val_mse: 4.8585e-07
# Epoch 88/100
# 157/157 [==============================] - 3s 21ms/step - loss: 4.9043e-07 - mse: 4.9043e-07 - val_loss: 7.4714e-07 - val_mse: 7.4714e-07
# Epoch 89/100
# 157/157 [==============================] - 3s 20ms/step - loss: 5.2825e-07 - mse: 5.2825e-07 - val_loss: 4.3786e-07 - val_mse: 4.3786e-07
# Epoch 90/100
# 157/157 [==============================] - 3s 21ms/step - loss: 4.8000e-07 - mse: 4.8000e-07 - val_loss: 4.0322e-07 - val_mse: 4.0322e-07
# Epoch 91/100
# 157/157 [==============================] - 4s 21ms/step - loss: 5.3564e-07 - mse: 5.3564e-07 - val_loss: 5.7418e-07 - val_mse: 5.7418e-07
# Epoch 92/100
# 157/157 [==============================] - 4s 22ms/step - loss: 4.3049e-07 - mse: 4.3049e-07 - val_loss: 3.5983e-07 - val_mse: 3.5983e-07
# Epoch 93/100
# 157/157 [==============================] - 3s 21ms/step - loss: 4.5408e-07 - mse: 4.5408e-07 - val_loss: 9.1551e-07 - val_mse: 9.1551e-07
# Epoch 94/100
# 157/157 [==============================] - 3s 20ms/step - loss: 5.2656e-07 - mse: 5.2656e-07 - val_loss: 4.3617e-07 - val_mse: 4.3617e-07
# Epoch 95/100
# 157/157 [==============================] - 4s 21ms/step - loss: 4.8362e-07 - mse: 4.8362e-07 - val_loss: 4.6067e-07 - val_mse: 4.6067e-07
# Epoch 96/100
# 157/157 [==============================] - 4s 21ms/step - loss: 4.0295e-07 - mse: 4.0295e-07 - val_loss: 5.5492e-07 - val_mse: 5.5492e-07
# Epoch 97/100
# 157/157 [==============================] - 3s 20ms/step - loss: 6.8662e-07 - mse: 6.8662e-07 - val_loss: 3.4247e-07 - val_mse: 3.4247e-07
# Epoch 98/100
# 157/157 [==============================] - 3s 20ms/step - loss: 3.3931e-07 - mse: 3.3931e-07 - val_loss: 3.8434e-07 - val_mse: 3.8434e-07
# Epoch 99/100
# 157/157 [==============================] - 4s 22ms/step - loss: 3.8602e-07 - mse: 3.8602e-07 - val_loss: 5.7487e-07 - val_mse: 5.7487e-07
# Epoch 100/100
# 157/157 [==============================] - 3s 21ms/step - loss: 3.8354e-07 - mse: 3.8354e-07 - val_loss: 1.0779e-06 - val_mse: 1.0779e-06

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train loss')
plt.plot(history.history['val_loss'], label='Validation loss')

# Adding labels and title
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.title('Training and Validation Loss Curves')
plt.yscale("log")
plt.legend()
plt.show()

# %% [markdown]
# ## Prediction on the test data in closed-loop
#
# We compare two different predictions on the test data:
# #### 1. Short-term prediction:
# - This demonstrates how long the short-term prediction of the LSTM corresponds to the reference solution. Because the systems is chaotic, any two close trajectories will seperate after a given time. We expect a prediction of at least 1 Lyapunov time.
#
# #### 2. Long-term prediction:
# - This demonstrates how statistical prediction of the LSTM and allows us to understand if the network reproduces the long-term behaviour (sometimes referred as climate) of the chaotic system.

# %%
# take a random time window from the test data
N_start = np.random.randint(len(U_test)-10000)
single_window = np.reshape(U_test[N_start:N_start+window_size, :], newshape=(1, window_size, 3))
prediction = tf_lstm.closed_loop_prediction(tf.convert_to_tensor(single_window), prediction_length=1000)

# %%
N_plot = min(10 * N_lyap,prediction.shape[0], U_rk4[N_start:, :].shape[0])
# Define time steps
time_steps = np.arange(0, N_plot * dt, dt) / t_lyap
prediction_plot = prediction
reference_plot = U_test[N_start:N_start+prediction.shape[0], :] 
# Create a figure with three subplots
fig, axes = plt.subplots(3, 1)

# Plot U_test for the first feature
axes[0].plot(time_steps[:N_plot], reference_plot[:N_plot, 0], color='black', label='Reference')
axes[0].plot(time_steps[:N_plot], prediction_plot[:N_plot, 0], color='red', linestyle='dashed', label=' Prediction')
axes[0].set_ylabel("x")
axes[0].set_xlabel("LT")

# Plot U_test for the second feature
axes[1].plot(time_steps, reference_plot[:N_plot, 1], color='black', label='Reference')
axes[1].plot(time_steps, prediction_plot[:N_plot, 1], color='red', linestyle='dashed', label=' Prediction')
axes[1].set_ylabel("y")
axes[1].set_xlabel("LT")
axes[1].legend(loc='upper left', bbox_to_anchor=(1, 1))

# Plot prediction and U_test for the third feature
axes[2].plot(time_steps[:N_plot], reference_plot[:N_plot, 2], color='black', label='Reference')
axes[2].plot(time_steps[:N_plot], prediction_plot[:N_plot, 2], color='red', linestyle='dashed', label='LSTM Prediction')
axes[2].set_ylabel("z")
axes[2].set_xlabel("LT")

# Add a title for the entire figure
fig.suptitle("Comparison of LSTM Prediction and Reference")
# Adjust layout for better spacing
plt.tight_layout()
# Show the plot
plt.show()

# %%
def stats_lorenz63(prediction_length, single_window):
    prediction = tf_lstm.closed_loop_prediction(single_window, prediction_length=prediction_length)
    Ys_t = prediction

        
    # Calculate the integral of the kde between 10 and 20:
    xmin, xmax = -1,1 
    n_bins = 50
    x = np.linspace(xmin,xmax,n_bins)
    
    fig, axs = plt.subplots(1,3)
    
    fig.suptitle('Probability Density Function (PDF)')

    fig.set_figheight(4)
    fig.set_figwidth(16)

    for i in range(dim):
        signal = U_test[:prediction_length,i]
        signal_p  = Ys_t[:prediction_length,i] #predicted closed loop
        
        kde = stats.gaussian_kde(signal)
        kde_p = stats.gaussian_kde(signal_p)
            
        axs[i].plot(x,kde(x),color='black', label='Reference')
        axs[i].plot(x,kde_p(x), color='red', linestyle='dashed', label='LSTM Prediction')
        axs[i].set_ylabel('PDF')

    axs[0].set_xlabel('$x$')
    axs[1].set_xlabel('$y$')
    axs[2].set_xlabel('$z$')
    plt.legend()    
    
    return(Ys_t)

# %%
prediction_length = 50*N_lyap # How many lyapunov times to generate for statistical predictions
U_pred_lstm = stats_lorenz63(prediction_length, single_window)
plt.show()

# %%
fig = plt.figure(figsize=(12, 5))

# First subplot for U_rk4
ax1 = fig.add_subplot(121, projection='3d')
fig.subplots_adjust(left=0, right=0.55, bottom=0, top=1)

# Make the line multi-coloured by plotting it in segments of length s which
# change in colour across the whole time series.
n = len(U_rk4[:10000])
s = 100
cmap = plt.cm.winter  # winter

for i in range(0, n - s, s):
    ax1.plot(U_rk4[i:i+s+1, 0], U_rk4[i:i+s+1, 1], U_rk4[i:i+s+1, 2], color=cmap(i/n), alpha=0.4)

ax1.set_title('Reference Attractor ')

# Second subplot for U_pred_lstm
ax2 = fig.add_subplot(122, projection='3d', sharex=ax1, sharey=ax1, sharez=ax1)
fig.subplots_adjust(left=0.55, right=1, bottom=0, top=1)

# Make the line multi-coloured by plotting it in segments of length s which
# change in colour across the whole time series.
for i in range(0, n - s, s):
    ax2.plot(U_pred_lstm[i:i+s+1, 0], U_pred_lstm[i:i+s+1, 1], U_pred_lstm[i:i+s+1, 2], color=cmap(i/n), alpha=0.4)

ax2.set_title('LSTM Attractor')

plt.show()

# %%
LEs_lstm = compute_lyapunov_exp_lstm(single_window, tf_lstm, 100*N_lyap, dim=3)
# Out:
# Finished on Transient
# Inside closed loop i = 10000, Time: 78.88681769371033
# Lyapunov exponents: [ 8.22988468e-01  1.57750295e-03 -1.33651943e+01]
# Final Lyapunov exponents: [ 8.25124429e-01  4.24645735e-03 -1.33650256e+01]

# %%
plt.plot(np.arange(len(LEs_lstm)*dt, step=dt), LEs_lstm)
plt.title("Covergence of LSTM Lyapunov exponents")
plt.ylabel("LEs")
plt.xlabel(r"$N_{lyap}$")
# Out:
# Text(0.5, 0, '$N_{lyap}$')
