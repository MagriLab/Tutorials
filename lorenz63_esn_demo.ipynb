# %%
import matplotlib.pyplot as plt
import numpy as np
import sys
from dynamicalsystems import solve_rk4, lorenz63
sys.path.append('../')
from esn.utils import errors, scalers
from esn.validation import validate, set_ESN
from esn.esn import ESN

# %% [markdown]
# # Generate the data:
# Solve the Lorenz 63 system using RK4. The parameters and inital condition are selected to ensure the system is chaotic.

# %%
dim = 3
# Parameters to ensure the system is chaotic
params = [2.667, 28, 10]  # beta, rho, sigma
u0 = np.array([0.0, 1.0, 1.0])  # initial condition

dt = 0.05  # time step
t_lyap = 0.9**(-1)  # Lyapunov time

N_lyap = int(t_lyap/dt)
N_trans = 0  # initial transient to discard
N_total = 1000*N_lyap + N_trans
time_array, U_rk4, derU = solve_rk4(lorenz63, N_total, dt, u0=u0, params=params)
upsampling=1
time_array = time_array[N_trans::upsampling]
U_rk4 = U_rk4[N_trans::upsampling, :dim]  # remove the initial transient

# %%
fig, axs = plt.subplots(3, 1, sharex=True)
for i in range(3):
    axs[i].plot(time_array[:1000], U_rk4[:1000, i])

axs[0].set_ylabel('x')
axs[1].set_ylabel('y')
axs[2].set_ylabel('z')
# Out:
# Text(0, 0.5, 'z')

# %%
# for i in [1, 5, 10]:
#     dt = 0.01*i  # time step
#     t_lyap = 0.9**(-1)  # Lyapunov time

#     N_lyap = int(t_lyap/dt)
#     N_trans = 2000  # initial transient to discard
#     N_total = 10000*dt+N_trans
#     time_array, U_rk4, derU = solve_rk4(lorenz63, N_total, dt, u0=u0, params=params)
#     U_rk4 = U_rk4[N_trans:, :dim]  # remove the initial transient
#     plt.plot(time_array[:100], U_rk4[:100], 'x', label=f"{dt}")
# plt.legend()

# %% [markdown]
# Prepare the training, validation and test data. Allow for a washout phase in the reservoir.

# %%
# set sizes
washout_size = 100
train_size = 10000
val_size = 5000
test_washout_size = 100

# Extract the shape of the original data
total_samples, num_features = U_rk4.shape

# Split the data into different datasets
U_washout = U_rk4[:washout_size, :]
U_train_input = U_rk4[washout_size:washout_size + train_size, :]
U_train_label = U_rk4[washout_size + 1: washout_size + train_size + 1, :]
U_val_input = U_rk4[washout_size + train_size: washout_size + train_size + val_size, :]
U_val_label = U_rk4[washout_size + train_size + 1: washout_size + train_size + val_size + 1, :]
U_test_washout = U_rk4[washout_size + train_size + val_size:washout_size + train_size + val_size + test_washout_size, :]
U_test = U_rk4[washout_size + train_size + val_size + test_washout_size:, :]

# Print shapes of datasets
print(f"Training data shape: {U_train_input.shape}")
print(f"U_val shape: {U_val_input.shape}")
print(f"U_test shape: {U_test.shape}")
# Out:
# Training data shape: (10000, 3)
# U_val shape: (5000, 3)
# U_test shape: (6801, 3)

# %% [markdown]
# # Training and Validation of ESNs

# %%
# specify which hyperparameters to search, e.g., spectral_radius, input_scaling, leak_factor
param_names = ['spectral_radius', 'input_scaling', 'tikhonov']

# range for hyperparameters 
spec_in = 0.1
spec_end = 1.0
in_scal_in = 0.1
in_scal_end = 10.0
tikh_in = 1e-9
tikh_out= 1e-3
grid_range = [[spec_in, spec_end], [in_scal_in, in_scal_end], [tikh_in, tikh_out]]


# how to scale the search for each hyperparameter in the given range, uniform or in log10
param_scales = ['uniform', 'log10', 'log10']

# scale the ranges
for i in range(len(grid_range)):
    for j in range(2):
        scaler = getattr(scalers, param_scales[i])
        grid_range[i][j] = scaler(grid_range[i][j])

N_washout = 40 # number of washout steps
N_val = 50  # number of validation steps

# fixed properties of the ESN
ESN_dict = {'reservoir_size': 300,
            'dimension': dim,
            'reservoir_connectivity': 3, 
            'input_bias':np.array([1.0]),
            'output_bias':np.array([1.0]),
            'reservoir_weights_mode':"erdos_renyi1",
            # 'r2_mode': True,
            'input_weights_mode': 'sparse_grouped'
            }
# tikhonov = 1e-6

min_dict = validate(
    grid_range=grid_range, 
    param_names=param_names, 
    param_scales=param_scales, 
    n_calls=10, # number of total trials  
    n_initial_points=5, # number of initial trials before bayesian optimization
    ESN_dict=ESN_dict, 
    U_washout_train=U_washout,
    n_realisations=3, # number of random ESN realisations
    U_train=U_train_input,
    Y_train=U_train_label, 
    U_val=U_val_input,
    Y_val=U_val_label,
    n_folds=2, # number of folds, i.e., validation time series that start from random time instances 
    N_washout_steps=N_washout, 
    N_val_steps=N_val, 
    random_seed=20, # random seed for the bayesian optimization
    error_measure=errors.rmse) # error measure to optimize over
# Out:
# Input to run_gp:([Real(low=0.1, high=1.0, prior='uniform', transform='identity'), Real(low=-1.0, high=1.0, prior='uniform', transform='identity'), Integer(low=-9.0, high=-3.0, prior='uniform', transform='identity')], 10, 5, 20)
# --NEW RUN-- 1
# Realisation: 0
# spectral_radius 0.6335601564025166
# input_scaling 4.881255012149711
# tikhonov 9.999999999999999e-05
#
#
# Val regime: 0
# Fold: 0 , fold error:  100.79976553553263
# Fold: 1 , fold error:  8.602225563312084
# Val regime error: 54.70099554942236
# Realisation error: 54.70099554942236
#
#
# Realisation: 1
# spectral_radius 0.6335601564025166
# input_scaling 4.881255012149711
# tikhonov 9.999999999999999e-05
#
#
# Val regime: 0
# Fold: 0 , fold error:  981.1633625640104
# Fold: 1 , fold error:  13.005612138635467
# Val regime error: 497.08448735132293
# Realisation error: 497.08448735132293
#
#
# Realisation: 2
# spectral_radius 0.6335601564025166
# input_scaling 4.881255012149711
# tikhonov 9.999999999999999e-05
#
#
# Val regime: 0
# Fold: 0 , fold error:  733.4454413193838
# Fold: 1 , fold error:  8.078441003825692
# Val regime error: 370.76194116160474
# Realisation error: 370.76194116160474
#
#
# Run 1 error: 307.51580802078337
#
#
# --NEW RUN-- 2
# Realisation: 0
# spectral_radius 0.8625265649057131
# input_scaling 1.7665559365643206
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  3.1428944767585967
# Fold: 1 , fold error:  3.5771678374636835
# Val regime error: 3.3600311571111403
# Realisation error: 3.3600311571111403
#
#
# Realisation: 1
# spectral_radius 0.8625265649057131
# input_scaling 1.7665559365643206
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  1.869420892064996
# Fold: 1 , fold error:  742.4966720586704
# Val regime error: 372.1830464753677
# Realisation error: 372.1830464753677
#
#
# Realisation: 2
# spectral_radius 0.8625265649057131
# input_scaling 1.7665559365643206
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  8.429752657559694
# Fold: 1 , fold error:  12.152705613076927
# Val regime error: 10.29122913531831
# Realisation error: 10.29122913531831
#
#
# Run 2 error: 128.6114355892657
#
#
# --NEW RUN-- 3
# Realisation: 0
# spectral_radius 0.3677811458900251
# input_scaling 0.12984521643751779
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  0.0036366806888869082
# Fold: 1 , fold error:  0.002229310501926217
# Val regime error: 0.0029329955954065625
# Realisation error: 0.0029329955954065625
#
#
# Realisation: 1
# spectral_radius 0.3677811458900251
# input_scaling 0.12984521643751779
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  0.0661801592392136
# Fold: 1 , fold error:  0.16283049173915087
# Val regime error: 0.11450532548918224
# Realisation error: 0.11450532548918224
#
#
# Realisation: 2
# spectral_radius 0.3677811458900251
# input_scaling 0.12984521643751779
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  0.0063888561651062525
# Fold: 1 , fold error:  0.01079949330694837
# Val regime error: 0.008594174736027312
# Realisation error: 0.008594174736027312
#
#
# Run 3 error: 0.04201083194020538
#
#
# --NEW RUN-- 4
# Realisation: 0
# spectral_radius 0.529898605589215
# input_scaling 4.210536704211821
# tikhonov 1e-06
#
#
# Val regime: 0
# Fold: 0 , fold error:  4.850022719426918
# Fold: 1 , fold error:  0.5650302825216167
# Val regime error: 2.7075265009742675
# Realisation error: 2.7075265009742675
#
#
# Realisation: 1
# spectral_radius 0.529898605589215
# input_scaling 4.210536704211821
# tikhonov 1e-06
#
#
# Val regime: 0
# Fold: 0 , fold error:  10.5452411821106
# Fold: 1 , fold error:  6340.107032108578
# Val regime error: 3175.3261366453444
# Realisation error: 3175.3261366453444
#
#
# Realisation: 2
# spectral_radius 0.529898605589215
# input_scaling 4.210536704211821
# tikhonov 1e-06
#
#
# Val regime: 0
# Fold: 0 , fold error:  18.410107164869558
# Fold: 1 , fold error:  23.912378835192175
# Val regime error: 21.161243000030865
# Realisation error: 21.161243000030865
#
#
# Run 4 error: 1066.3983020487833
#
#
# --NEW RUN-- 5
# Realisation: 0
# spectral_radius 0.4535063164907469
# input_scaling 4.7006457927320575
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  7599.816964051054
# Fold: 1 , fold error:  15.830747494887655
# Val regime error: 3807.823855772971
# Realisation error: 3807.823855772971
#
#
# Realisation: 1
# spectral_radius 0.4535063164907469
# input_scaling 4.7006457927320575
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  2.4540879883937405
# Fold: 1 , fold error:  4.518030876265892
# Val regime error: 3.4860594323298164
# Realisation error: 3.4860594323298164
#
#
# Realisation: 2
# spectral_radius 0.4535063164907469
# input_scaling 4.7006457927320575
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  11.048941328292655
# Fold: 1 , fold error:  54661.72070188293
# Val regime error: 27336.38482160561
# Realisation error: 27336.38482160561
#
#
# Run 5 error: 10382.564912270303
#
#
# --NEW RUN-- 6
# Realisation: 0
# Not valid reservoir encountered, changing seed.
# spectral_radius 0.3769194704150767
# input_scaling 0.12839328484183793
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  0.07359257322503773
# Fold: 1 , fold error:  0.02252285596961668
# Val regime error: 0.0480577145973272
# Realisation error: 0.0480577145973272
#
#
# Realisation: 1
# spectral_radius 0.3769194704150767
# input_scaling 0.12839328484183793
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  0.006400503733682896
# Fold: 1 , fold error:  0.07807682609824429
# Val regime error: 0.04223866491596359
# Realisation error: 0.04223866491596359
#
#
# Realisation: 2
# spectral_radius 0.3769194704150767
# input_scaling 0.12839328484183793
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  0.006708207878428236
# Fold: 1 , fold error:  0.22453490217564945
# Val regime error: 0.11562155502703884
# Realisation error: 0.11562155502703884
#
#
# Run 6 error: 0.06863931151344321
#
#
# --NEW RUN-- 7
# Realisation: 0
# spectral_radius 0.44521426986914237
# input_scaling 1.065807724062216
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  0.16804951619950861
# Fold: 1 , fold error:  0.2987911650445278
# Val regime error: 0.23342034062201822
# Realisation error: 0.23342034062201822
#
#
# Realisation: 1
# Not valid reservoir encountered, changing seed.
# spectral_radius 0.44521426986914237
# input_scaling 1.065807724062216
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  11.040690436940704
# Fold: 1 , fold error:  7.232490653547113
# Val regime error: 9.136590545243909
# Realisation error: 9.136590545243909
#
#
# Realisation: 2
# spectral_radius 0.44521426986914237
# input_scaling 1.065807724062216
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  4.313753481488119
# Fold: 1 , fold error:  1.2678490721771498
# Val regime error: 2.7908012768326342
# Realisation error: 2.7908012768326342
#
#
# Run 7 error: 4.053604054232854
#
#
# --NEW RUN-- 8
# Realisation: 0
# spectral_radius 0.8396140101788732
# input_scaling 1.540715552114285
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  0.9844875263536234
# Fold: 1 , fold error:  0.2218339803094678
# Val regime error: 0.6031607533315456
# Realisation error: 0.6031607533315456
#
#
# Realisation: 1
# spectral_radius 0.8396140101788732
# input_scaling 1.540715552114285
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  1.4218787670426918
# Fold: 1 , fold error:  4.443832675562331
# Val regime error: 2.9328557213025115
# Realisation error: 2.9328557213025115
#
#
# Realisation: 2
# spectral_radius 0.8396140101788732
# input_scaling 1.540715552114285
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  1246.133615385966
# Fold: 1 , fold error:  2.2285339437656346
# Val regime error: 624.1810746648658
# Realisation error: 624.1810746648658
#
#
# Run 8 error: 209.23903037983328
#
#
# --NEW RUN-- 9
# Realisation: 0
# spectral_radius 0.38872514211531795
# input_scaling 1.0355152185173906
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  3.5097798578001718
# Fold: 1 , fold error:  1.957372089845478
# Val regime error: 2.733575973822825
# Realisation error: 2.733575973822825
#
#
# Realisation: 1
# spectral_radius 0.38872514211531795
# input_scaling 1.0355152185173906
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  11.167528920049097
# Fold: 1 , fold error:  7.952018078103465
# Val regime error: 9.55977349907628
# Realisation error: 9.55977349907628
#
#
# Realisation: 2
# spectral_radius 0.38872514211531795
# input_scaling 1.0355152185173906
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  0.1980794745955664
# Fold: 1 , fold error:  5.656682971764112
# Val regime error: 2.927381223179839
# Realisation error: 2.927381223179839
#
#
# Run 9 error: 5.0735768986929815
#
#
# --NEW RUN-- 10
# Realisation: 0
# spectral_radius 0.3710790700245775
# input_scaling 0.12935128492858955
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  0.01358301477692986
# Fold: 1 , fold error:  0.0043728174721766825
# Val regime error: 0.008977916124553271
# Realisation error: 0.008977916124553271
#
#
# Realisation: 1
# spectral_radius 0.3710790700245775
# input_scaling 0.12935128492858955
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  0.030021053984272513
# Fold: 1 , fold error:  0.011094800368288768
# Val regime error: 0.02055792717628064
# Realisation error: 0.02055792717628064
#
#
# Realisation: 2
# spectral_radius 0.3710790700245775
# input_scaling 0.12935128492858955
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  0.013916590854905975
# Fold: 1 , fold error:  0.009108574141478353
# Val regime error: 0.011512582498192165
# Realisation error: 0.011512582498192165
#
#
# Run 10 error: 0.013682808599675361
#
#
# {'f': array([0.01368281, 0.04201083, 0.06863931, 4.05360405, 5.0735769 ]), 'spectral_radius': array([0.37107907, 0.36778115, 0.37691947, 0.44521427, 0.38872514]), 'input_scaling': array([0.12935128, 0.12984522, 0.12839328, 1.06580772, 1.03551522]), 'tikhonov': array([1.e-07, 1.e-07, 1.e-07, 1.e-07, 1.e-07])}

# %% [markdown]
# # Train the ESN with the best hyperparameter and predict on the test set

# %%
my_ESN = ESN(reservoir_size=ESN_dict["reservoir_size"],
             dimension=dim,
             reservoir_connectivity=ESN_dict["reservoir_connectivity"],
             spectral_radius=min_dict['spectral_radius'][0],
             input_scaling=min_dict['input_scaling'][0],
             tikhonov=min_dict['tikhonov'][0],
             input_weights_mode=ESN_dict["input_weights_mode"],
             input_seeds=[0, 1, 2],
             reservoir_seeds=[3, 4])

my_ESN.train(U_washout, U_train_input, U_train_label)
reservoir, prediction = my_ESN.closed_loop_with_washout(U_test_washout, 2000)
# Out:
# Input normalization is changed, training must be done again.
# Input scaling is set to 1, set it separately if necessary.
# Input weights are rescaled with the new input scaling.
# Spectral radius is set to 1, set it separately if necessary.
# Reservoir weights are rescaled with the new spectral radius.

# %%
N_plot = 20 * N_lyap
# Define time steps
time_steps = np.arange(0, N_plot * dt, dt) / t_lyap

# Create a figure with three subplots
fig, axes = plt.subplots(3, 1)

# Plot U_test for the first feature
axes[0].plot(time_steps[:N_plot], U_test[:N_plot, 0], color='black', label='Reference')
axes[0].plot(time_steps[:N_plot], prediction[:N_plot, 0], color='red', linestyle='dashed', label='ESN Prediction')
axes[0].set_ylabel("x")
axes[0].set_xlabel("t [LT]")

# Plot U_test for the second feature
axes[1].plot(time_steps, U_test[:N_plot, 1], color='black', label='Reference')
axes[1].plot(time_steps, prediction[:N_plot, 1], color='red', linestyle='dashed', label='ESN Prediction')
axes[1].set_ylabel("y")
axes[1].set_xlabel("t [LT]")
axes[1].legend(loc='upper left', bbox_to_anchor=(1, 1))

# Plot prediction and U_test for the third feature
axes[2].plot(time_steps[:N_plot], U_test[:N_plot, 2], color='black', label='Reference')
axes[2].plot(time_steps[:N_plot], prediction[:N_plot, 2], color='red', linestyle='dashed', label='ESN Prediction')
axes[2].set_ylabel("z")
axes[2].set_xlabel("t [LT]")

# Add a title for the entire figure
fig.suptitle("Comparison of ESN Prediction and Reference - Test Data")
# Adjust layout for better spacing
plt.tight_layout()
# Show the plot
# plt.savefig('full_pred011.png', dpi=100)
plt.show()

# %%
N_plot = 15 * N_lyap
# Define time steps
time_steps = np.arange(0, N_plot * dt, dt) / t_lyap

# # Create a figure with three subplots
# fig, axes = plt.subplots(2, 1)

# Plot U_test for the first feature
plt.plot(time_steps[:N_plot], U_test[:N_plot, 0], color='black', label='Reference')
plt.plot(time_steps[:N_plot], prediction[:N_plot, 0], color='red', linestyle='dashed', label='ESN Prediction')
plt.ylabel("x")
plt.xlabel("t [LT]")



# Add a title for the entire figure
plt.title("Comparison of ESN Prediction and Reference - Test Data")
# Adjust layout for better spacing
plt.tight_layout()
# Show the plot
# plt.show()
plt.savefig("ESN_variablex_01.png", dpi=100)
