# %%
import matplotlib.pyplot as plt
import numpy as np
import sys
from dynamicalsystems.equations import solve_rk4, lorenz63
# sys.path.append('')
from esn.utils import errors, scalers
from esn.validation import validate, set_ESN
from esn.esn import ESN

# %% [markdown]
# # Generate the data:
# Solve the Lorenz 63 system using RK4. The parameters and inital condition are selected to ensure the system is chaotic.

# %%
dim = 3
# Parameters to ensure the system is chaotic
params = [2.667, 28, 10]  # beta, rho, sigma
u0 = np.array([0.0, 1.0, 1.0])  # initial condition

dt = 0.01 # time step
t_lyap = 0.9**(-1)  # Lyapunov time

N_lyap = int(t_lyap/dt)
N_trans = 0  # initial transient to discard
N_total = 1000*N_lyap + N_trans
time_array, U_rk4, derU = solve_rk4(lorenz63, N_total, dt, u0=u0, params=params)
upsampling=1
time_array = time_array[N_trans::upsampling]
U_rk4 = U_rk4[N_trans::upsampling, :dim]  # remove the initial transient

# %%
fig, axs = plt.subplots(3, 1, sharex=True)
for i in range(3):
    axs[i].plot(time_array[:1000], U_rk4[:1000, i])

axs[0].set_ylabel('x')
axs[1].set_ylabel('y')
axs[2].set_ylabel('z')
# Out:
# Text(0, 0.5, 'z')

# %% [markdown]
# Prepare the training, validation and test data. Allow for a washout phase in the reservoir.

# %%
# set sizes
washout_size = 100
train_size = 10000
val_size = 5000
test_washout_size = 100

# Extract the shape of the original data
total_samples, num_features = U_rk4.shape

# Split the data into different datasets
U_washout = U_rk4[:washout_size, :]
U_train_input = U_rk4[washout_size:washout_size + train_size, :]
U_train_label = U_rk4[washout_size + 1: washout_size + train_size + 1, :]
U_val_input = U_rk4[washout_size + train_size: washout_size + train_size + val_size, :]
U_val_label = U_rk4[washout_size + train_size + 1: washout_size + train_size + val_size + 1, :]
U_test_washout = U_rk4[washout_size + train_size + val_size:washout_size + train_size + val_size + test_washout_size, :]
U_test = U_rk4[washout_size + train_size + val_size + test_washout_size:, :]

# Print shapes of datasets
print(f"Training data shape: {U_train_input.shape}")
print(f"U_val shape: {U_val_input.shape}")
print(f"U_test shape: {U_test.shape}")
# Out:
# Training data shape: (10000, 3)
# U_val shape: (5000, 3)
# U_test shape: (95801, 3)

# %% [markdown]
# # Training and Validation of ESNs

# %%
# specify which hyperparameters to search, e.g., spectral_radius, input_scaling, leak_factor
param_names = ['spectral_radius', 'input_scaling', 'tikhonov']

# range for hyperparameters 
spec_in = 0.1
spec_end = 1.0
in_scal_in = 0.1
in_scal_end = 10.0
tikh_in = 1e-9
tikh_out= 1e-3
grid_range = [[spec_in, spec_end], [in_scal_in, in_scal_end], [tikh_in, tikh_out]]


# how to scale the search for each hyperparameter in the given range, uniform or in log10
param_scales = ['uniform', 'log10', 'log10']

# scale the ranges
for i in range(len(grid_range)):
    for j in range(2):
        scaler = getattr(scalers, param_scales[i])
        grid_range[i][j] = scaler(grid_range[i][j])

N_washout = 40 # number of washout steps
N_val = 50  # number of validation steps

# fixed properties of the ESN
ESN_dict = {'reservoir_size': 100,
            'dimension': dim,
            'reservoir_connectivity': 3, 
            'input_bias':np.array([1.0]),
            'output_bias':np.array([1.0]),
            'reservoir_weights_mode':"erdos_renyi1",
            # 'r2_mode': True,
            'input_weights_mode': 'sparse_grouped'
            }
# tikhonov = 1e-6

min_dict = validate(
    grid_range=grid_range, 
    param_names=param_names, 
    param_scales=param_scales, 
    n_calls=10, # number of total trials  
    n_initial_points=5, # number of initial trials before bayesian optimization
    ESN_dict=ESN_dict, 
    U_washout_train=U_washout,
    n_realisations=3, # number of random ESN realisations
    U_train=U_train_input,
    Y_train=U_train_label, 
    U_val=U_val_input,
    Y_val=U_val_label,
    n_folds=2, # number of folds, i.e., validation time series that start from random time instances 
    N_washout_steps=N_washout, 
    N_val_steps=N_val, 
    random_seed=20, # random seed for the bayesian optimization
    error_measure=errors.rmse) # error measure to optimize over
# Out:
# Input to run_gp:([Real(low=0.1, high=1.0, prior='uniform', transform='identity'), Real(low=-1.0, high=1.0, prior='uniform', transform='identity'), Integer(low=-9.0, high=-3.0, prior='uniform', transform='identity')], 10, 5, 20)
# --NEW RUN-- 1
# Realisation: 0
# spectral_radius 0.6335601564025166
# input_scaling 4.881255012149711
# tikhonov 9.999999999999999e-05
#
#
# Val regime: 0
# Fold: 0 , fold error:  10.380925239244029
# Fold: 1 , fold error:  1480.297504230125
# Val regime error: 745.3392147346846
# Realisation error: 745.3392147346846
#
#
# Realisation: 1
# spectral_radius 0.6335601564025166
# input_scaling 4.881255012149711
# tikhonov 9.999999999999999e-05
#
#
# Val regime: 0
# Fold: 0 , fold error:  1628.8047812520051
# Fold: 1 , fold error:  11.06478314930792
# Val regime error: 819.9347822006565
# Realisation error: 819.9347822006565
#
#
# Realisation: 2
# spectral_radius 0.6335601564025166
# input_scaling 4.881255012149711
# tikhonov 9.999999999999999e-05
#
#
# Val regime: 0
# Fold: 0 , fold error:  163.67589196559328
# Fold: 1 , fold error:  23.22589913731534
# Val regime error: 93.45089555145431
# Realisation error: 93.45089555145431
#
#
# Run 1 error: 552.9082974955985
#
#
# --NEW RUN-- 2
# Realisation: 0
# spectral_radius 0.8625265649057131
# input_scaling 1.7665559365643206
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  1167.3630779066368
# Fold: 1 , fold error:  5.083898313025457
# Val regime error: 586.2234881098311
# Realisation error: 586.2234881098311
#
#
# Realisation: 1
# spectral_radius 0.8625265649057131
# input_scaling 1.7665559365643206
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  7523.475690625733
# Fold: 1 , fold error:  10.384729357175072
# Val regime error: 3766.930209991454
# Realisation error: 3766.930209991454
#
#
# Realisation: 2
# Not valid reservoir encountered, changing seed.
# spectral_radius 0.8625265649057131
# input_scaling 1.7665559365643206
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  10.475361927161224
# Fold: 1 , fold error:  3.3180043412228892
# Val regime error: 6.896683134192056
# Realisation error: 6.896683134192056
#
#
# Run 2 error: 1453.3501270784925
#
#
# --NEW RUN-- 3
# Realisation: 0
# spectral_radius 0.3677811458900251
# input_scaling 0.12984521643751779
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  0.005319985303921213
# Fold: 1 , fold error:  0.0071116189015654925
# Val regime error: 0.006215802102743353
# Realisation error: 0.006215802102743353
#
#
# Realisation: 1
# spectral_radius 0.3677811458900251
# input_scaling 0.12984521643751779
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  0.003589426737434236
# Fold: 1 , fold error:  0.0077748820304754445
# Val regime error: 0.00568215438395484
# Realisation error: 0.00568215438395484
#
#
# Realisation: 2
# spectral_radius 0.3677811458900251
# input_scaling 0.12984521643751779
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  0.006770699234919104
# Fold: 1 , fold error:  0.011468482604045052
# Val regime error: 0.009119590919482078
# Realisation error: 0.009119590919482078
#
#
# Run 3 error: 0.007005849135393424
#
#
# --NEW RUN-- 4
# Realisation: 0
# spectral_radius 0.529898605589215
# input_scaling 4.210536704211821
# tikhonov 1e-06
#
#
# Val regime: 0
# Fold: 0 , fold error:  6.4090473962794245
# Fold: 1 , fold error:  4284.159368471628
# Val regime error: 2145.284207933954
# Realisation error: 2145.284207933954
#
#
# Realisation: 1
# spectral_radius 0.529898605589215
# input_scaling 4.210536704211821
# tikhonov 1e-06
#
#
# Val regime: 0
# Fold: 0 , fold error:  8.773347932680293
# Fold: 1 , fold error:  22838.107755389086
# Val regime error: 11423.440551660884
# Realisation error: 11423.440551660884
#
#
# Realisation: 2
# spectral_radius 0.529898605589215
# input_scaling 4.210536704211821
# tikhonov 1e-06
#
#
# Val regime: 0
# Fold: 0 , fold error:  6.134286294999645
# Fold: 1 , fold error:  8.847361436762371
# Val regime error: 7.4908238658810085
# Realisation error: 7.4908238658810085
#
#
# Run 4 error: 4525.405194486906
#
#
# --NEW RUN-- 5
# Realisation: 0
# spectral_radius 0.4535063164907469
# input_scaling 4.7006457927320575
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  7.933996004595041
# Fold: 1 , fold error:  43938.38072783594
# Val regime error: 21973.157361920268
# Realisation error: 21973.157361920268
#
#
# Realisation: 1
# spectral_radius 0.4535063164907469
# input_scaling 4.7006457927320575
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  8.576825774454337
# Fold: 1 , fold error:  6.411514709457762
# Val regime error: 7.494170241956049
# Realisation error: 7.494170241956049
#
#
# Realisation: 2
# spectral_radius 0.4535063164907469
# input_scaling 4.7006457927320575
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  146231.45020835218
# Fold: 1 , fold error:  6.547580725781012
# Val regime error: 73118.99889453898
# Realisation error: 73118.99889453898
#
#
# Run 5 error: 31699.88347556707
#
#
# --NEW RUN-- 6
# Realisation: 0
# spectral_radius 0.8893755162446619
# input_scaling 0.1239590068861178
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  0.07271909967026939
# Fold: 1 , fold error:  6.596951770610157
# Val regime error: 3.334835435140213
# Realisation error: 3.334835435140213
#
#
# Realisation: 1
# spectral_radius 0.8893755162446619
# input_scaling 0.1239590068861178
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  0.01835061415919793
# Fold: 1 , fold error:  0.018785345867440975
# Val regime error: 0.018567980013319454
# Realisation error: 0.018567980013319454
#
#
# Realisation: 2
# spectral_radius 0.8893755162446619
# input_scaling 0.1239590068861178
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  0.09883409904011639
# Fold: 1 , fold error:  0.028015244023417443
# Val regime error: 0.06342467153176692
# Realisation error: 0.06342467153176692
#
#
# Run 6 error: 1.1389426955617665
#
#
# --NEW RUN-- 7
# Realisation: 0
# spectral_radius 0.939081656116022
# input_scaling 1.0072429071229743
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  750.9268958772541
# Fold: 1 , fold error:  819.5795707067795
# Val regime error: 785.2532332920168
# Realisation error: 785.2532332920168
#
#
# Realisation: 1
# spectral_radius 0.939081656116022
# input_scaling 1.0072429071229743
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  8.689008159905569
# Fold: 1 , fold error:  4.915529563988916
# Val regime error: 6.802268861947242
# Realisation error: 6.802268861947242
#
#
# Realisation: 2
# spectral_radius 0.939081656116022
# input_scaling 1.0072429071229743
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  372.50001464055305
# Fold: 1 , fold error:  337.2805125239296
# Val regime error: 354.89026358224135
# Realisation error: 354.89026358224135
#
#
# Run 7 error: 382.31525524540183
#
#
# --NEW RUN-- 8
# Realisation: 0
# spectral_radius 0.7966427912467551
# input_scaling 1.3431833476692123
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  197.93863177816664
# Fold: 1 , fold error:  3.6581568692680344
# Val regime error: 100.79839432371733
# Realisation error: 100.79839432371733
#
#
# Realisation: 1
# spectral_radius 0.7966427912467551
# input_scaling 1.3431833476692123
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  1535.6691526795948
# Fold: 1 , fold error:  8.200620582426534
# Val regime error: 771.9348866310107
# Realisation error: 771.9348866310107
#
#
# Realisation: 2
# spectral_radius 0.7966427912467551
# input_scaling 1.3431833476692123
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  2253.4163750071343
# Fold: 1 , fold error:  2439.1822417136555
# Val regime error: 2346.299308360395
# Realisation error: 2346.299308360395
#
#
# Run 8 error: 1073.010863105041
#
#
# --NEW RUN-- 9
# Realisation: 0
# spectral_radius 0.4134067690796789
# input_scaling 0.12933320136574053
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  0.014737414078354582
# Fold: 1 , fold error:  0.0060785074854902066
# Val regime error: 0.010407960781922394
# Realisation error: 0.010407960781922394
#
#
# Realisation: 1
# spectral_radius 0.4134067690796789
# input_scaling 0.12933320136574053
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  0.00670010415240406
# Fold: 1 , fold error:  0.0012577483476117963
# Val regime error: 0.003978926250007928
# Realisation error: 0.003978926250007928
#
#
# Realisation: 2
# spectral_radius 0.4134067690796789
# input_scaling 0.12933320136574053
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  0.004629438950491144
# Fold: 1 , fold error:  0.002201590384048701
# Val regime error: 0.003415514667269922
# Realisation error: 0.003415514667269922
#
#
# Run 9 error: 0.005934133899733415
#
#
# --NEW RUN-- 10
# Realisation: 0
# spectral_radius 1.0
# input_scaling 0.7861981482488478
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  415.13692547900774
# Fold: 1 , fold error:  199.13665573372302
# Val regime error: 307.13679060636537
# Realisation error: 307.13679060636537
#
#
# Realisation: 1
# spectral_radius 1.0
# input_scaling 0.7861981482488478
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  26.184108571529674
# Fold: 1 , fold error:  15.574464067484369
# Val regime error: 20.87928631950702
# Realisation error: 20.87928631950702
#
#
# Realisation: 2
# spectral_radius 1.0
# input_scaling 0.7861981482488478
# tikhonov 1e-07
#
#
# Val regime: 0
# Fold: 0 , fold error:  2018.6844628150152
# Fold: 1 , fold error:  1.6706506469213236
# Val regime error: 1010.1775567309683
# Realisation error: 1010.1775567309683
#
#
# Run 10 error: 446.0645445522802
#
#
# {'f': array([5.93413390e-03, 7.00584914e-03, 1.13894270e+00, 3.82315255e+02,
#        4.46064545e+02]), 'spectral_radius': array([0.41340677, 0.36778115, 0.88937552, 0.93908166, 1.        ]), 'input_scaling': array([0.1293332 , 0.12984522, 0.12395901, 1.00724291, 0.78619815]), 'tikhonov': array([1.e-07, 1.e-07, 1.e-07, 1.e-07, 1.e-07])}

# %% [markdown]
# # Train the ESN with the best hyperparameter and predict on the test set

# %%
my_ESN = ESN(reservoir_size=ESN_dict["reservoir_size"],
             dimension=dim,
             reservoir_connectivity=ESN_dict["reservoir_connectivity"],
             spectral_radius=min_dict['spectral_radius'][0],
             input_scaling=min_dict['input_scaling'][0],
             tikhonov=min_dict['tikhonov'][0],
             input_weights_mode=ESN_dict["input_weights_mode"],
             input_seeds=[0, 1, 2],
             reservoir_seeds=[3, 4])

my_ESN.train(U_washout, U_train_input, U_train_label)
reservoir, prediction = my_ESN.closed_loop_with_washout(U_test_washout, 10000)
# Out:
# Input normalization is changed, training must be done again.
# Input scaling is set to 1, set it separately if necessary.
# Input weights are rescaled with the new input scaling.
# Spectral radius is set to 1, set it separately if necessary.
# Reservoir weights are rescaled with the new spectral radius.

# %%
N_plot = 20 * N_lyap
# Define time steps
time_steps = np.arange(0, N_plot * dt, dt) / t_lyap

# Create a figure with three subplots
fig, axes = plt.subplots(3, 1)

# Plot U_test for the first feature
axes[0].plot(time_steps[:N_plot], U_test[:N_plot, 0], color='black', label='Reference')
axes[0].plot(time_steps[:N_plot], prediction[:N_plot, 0], color='red', linestyle='dashed', label='ESN Prediction')
axes[0].set_ylabel("x")
axes[0].set_xlabel("t [LT]")

# Plot U_test for the second feature
axes[1].plot(time_steps, U_test[:N_plot, 1], color='black', label='Reference')
axes[1].plot(time_steps, prediction[:N_plot, 1], color='red', linestyle='dashed', label='ESN Prediction')
axes[1].set_ylabel("y")
axes[1].set_xlabel("t [LT]")
axes[1].legend(loc='upper left', bbox_to_anchor=(1, 1))

# Plot prediction and U_test for the third feature
axes[2].plot(time_steps[:N_plot], U_test[:N_plot, 2], color='black', label='Reference')
axes[2].plot(time_steps[:N_plot], prediction[:N_plot, 2], color='red', linestyle='dashed', label='ESN Prediction')
axes[2].set_ylabel("z")
axes[2].set_xlabel("t [LT]")

# Add a title for the entire figure
fig.suptitle("Comparison of ESN Prediction and Reference - Test Data")
# Adjust layout for better spacing
plt.tight_layout()
# Show the plot
# plt.savefig('esn_prediction.png', dpi=100)
plt.show()
